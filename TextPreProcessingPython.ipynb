# %% [markdown]
# Maziar Izadi
#
# Data wrangling in Python
#
# Email: alpha.maziar

# %%
# Import required libraries

# Regular Expressions (REGeX)
import re
from nltk.probability import *

# Natural Language Toolkit
import nltk

# Functions creating iterators for efficient looping
import itertools
from itertools import chain
from itertools import groupby

# Convert a collection of text documents to a matrix of token counts
from sklearn.feature_extraction.text import CountVectorizer

# %%
# open the file and read the contents
data = []

# make sure you define the encoding format otherwise you might get this error: 
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 260893: character maps to <undefined>
with open('data.txt', encoding="utf8") as f:
    data = f.read().lower() # read the content and lower the letters (for consistency)

# %%
# make a pattern for REGEX to find and keep matching words only
pattern = re.compile(r"[a-zA-Z]+(?:[-'][a-zA-Z]+)?") 

# tokenise the words: match the pattern to file's content and tokenize the content
tokenised = pattern.findall(data)

# %%
# pass the length of the 'tokenised' series into a variable
tokenised_len = len(tokenised)

# indexing the tokens
indexes = [i for i, v in enumerate(tokenised) if v=='id' and i+1 < tokenised_len and tokenised[i+1]=='title']

# %%
# from itertools recipes
def pairwise(iterable, fillvalue=None):
    """
       This function iterates through the list of tokens and 
       creates sub list to include tokens related to one job ad only
    """
    a, b = iter(iterable), iter(iterable)
    next(b, None)
    return itertools.zip_longest(a, b, fillvalue=fillvalue)

# pairwise based on indexes in the last block and store in the 'tokenised' as a list
tokenised = [tokenised[i:j] for i,j in pairwise(indexes)]

# %% [markdown]
# - Exclude words less than 4 char:
#
# - I have kept all the tokens which are more than 3 characters and renamed the rest to 'to_removed
#
# - "to_remove" is added to "stopwords" list further down

# %%
tokenised = [[word if len(word) > 3 else "to_remove" for word in job] for job in tokenised]

# %% [markdown]
# ### Removing stopwords

# %%
# adding'to_removed' string to the list of stopwords
stopwords = []
with open('stopwords_en.txt',"a") as f:
    f.write("\nto_remove") #\n to shift to next line

# %%
with open('stopwords_en.txt') as f:
    stopwords = f.read().splitlines() #reading stopwords line and create stopwords as a list

# %%
# convert stopwords into set
# Python set is better choice than list. 
# Set runs much faster than lists in terms of searching a large number of hashable items

stopwordsset = set(stopwords)

# %%
def purifier(tokenList,remove_token):
    """
        This function takes two input (list of current tokens and list of tokens to be removed)
        The function converts the list into set to improve the performance
        and return a list of sets each of which include purified tokens
        and remove_token lists are removed
    """
    return [set(word for word in job if word not in remove_token) for job in tokenList]

# %%
# running 'purifier' function
tokenised = purifier(tokenised,stopwordsset)

# %% [markdown]
# You need to remove the words that appear only once in one job advertisement description, save them ( No duplication) as a txt file (refer to the required output). You will need to exclude those words in the generated vocabulary.

# %%
# Using chain() function to join all the words in all the job ads together by making a list
stop_wrds_removed_words = list(chain.from_iterable([word for word in job] for job in tokenised))
# convert the list of words into set to remove duplicates and create the set of vocabulary
stop_wrds_removed_vocab = set(stop_wrds_removed_words)
# passing the words in FreqDisrt() function to cound the number of token
# this function counts the number of times a word occurs in the whole corpus regardless which ad it is in.
fd = FreqDist(stop_wrds_removed_words)

# %%
# finding the Less Frequent Tokens.

# create a list of token which have occured more than once
# convert the list into set for performance improvement
once_only = set([k for k, v in fd.items() if v == 1])
# sort the set into alphabetical order
once_only = sorted(once_only)

set(once_only)
# Out:
# {'dobson',
#  'nurs',
#  'applianceengineerwhitegoods',
#  'rman',
#  'thereon',
#  'techniquesdelivery',
#  "steady's",
#  'assistantaylesbury',
#  'articulated',
#  'cary',
#  'managementprocess',
#  'multicontact',
#  'snack',
#  'perfmon',
#  'emulate',
#  'openedge',
#  'tredegar',
#  'caddesignerwithestimating',
#  'projectdriven',
#  'lookin',
#  'yacht',
#  'autocoded',
#  'opportuities',
#  'outcomesexperience',
#  'scenic',
#  'tewksbury',
#  'retrofit',
#  'xiexperience',
#  'cobol',
#  'declinature',
#  'announced',
#  'sticky',
#  'pcduproviders',
#  'airborne',
#  'achievedconduct',
#  'joel',
#  'projectmanagermefacilitiesmanagementwestlondon',
#  'poststudy',
#  'dunfermline',
#  'munirm',
#  'magnox',
#  'tolondonbridge',
#  'coldrooms',
#  'qualityrequired',
#  'unvented',
#  'wellcome',
#  'conwy',
#  'relationshipsacross',
#  'perfecting',
#  'workplease',
#  'remeasurement',
#  'bfms',
#  'minipiling',
#  'dualcom',
#  'rabbitmq',
#  'hospice',
#  'albeit',
#  'mariani',
#  'highintegrity',
#  'pyrometry',
#  'hfea',
#  'hang',
#  'recalibration',
#  'skinny',
#  'broadberryrisetechnical',
#  'liable',
#  'dcim',
#  'crash',
#  'diarised',
#  'anne',
#  'float',
#  'expeirence',
#  'confronting',
#  'privelege',
#  'desulphurisation',
#  'commissioningengineer',
#  'llangollen',
#  'objectrelational',
#  'attacks',
#  'vmaxvmwareexperience',
#  'withdrawn',
#  'tourism',
#  'burger',
#  'beneficialan',
#  'smartly',
#  'measuredexcellent',
#  'delve',
#  'cutlery',
#  'nonspecialist',
#  'diprlm',
#  'wellwritten',
#  'snrdigitaldesigner',
#  'substantively',
#  'redeemable',
#  'strgroup',
#  'elevationrecruitment',
#  'experiencejob',
#  'oppotunity',
#  'engineerstaffordshire',
#  'mckerr',
#  'microsoftcentric',
#  'blind',
#  'myplymouthbased',
#  'blur',
#  'gloucstershire',
#  'iphones',
#  'sherburn',
#  'servicefocused',
#  'qualifiation',
#  'checkyou',
#  'lineofbusiness',
#  'trole',
#  'thorpe',
#  'commischefluxuryfourstarhotelstraightshiftsdiscounts',
#  'acumenbeing',
#  'balustrade',
#  'erectionsupervisor',
#  'nusring',
#  'meads',
#  'oundle',
#  'burrelton',
#  'rcrm',
#  "eng's",
#  'hote',
#  'jevansbondrecruitment',
#  'defuse',
#  'twinflex',
#  'erience',
#  'artworker',
#  'lcnr',
#  'yearlocation',
#  'ofdesign',
#  'supervises',
#  'infrastructural',
#  'rehearsal',
#  'anglian',
#  'psychiatrist',
#  'heidenhim',
#  'managements',
#  'neilswr',
#  'heaton',
#  'posture',
#  'ecad',
#  'cathays',
#  'edinburgha',
#  'herceptin',
#  'tomrees',
#  'payrolls',
#  'researchadvert',
#  'traumatic',
#  'bordon',
#  'handledas',
#  'clientsaccount',
#  'pattester',
#  'residentail',
#  'frameworksexperience',
#  'primed',
#  'managementcontribute',
#  'transducers',
#  'codec',
#  'supreme',
#  'flue',
#  'electronicsemc',
#  'certificationsrequired',
#  'rumney',
#  'safetyrelated',
#  'dollars',
#  'enteral',
#  'straightaway',
#  'benefitscandidate',
#  'prioritis',
#  'nknowledge',
#  'servicesbeneficial',
#  'rmas',
#  'trackable',
#  'castro',
#  'hurco',
#  'teamsbudgets',
#  'midyear',
#  'telemarketers',
#  'combat',
#  'spectacle',
#  'electricalengineeringsupervisormobile',
#  'londonnearest',
#  'exerprience',
#  'sketch',
#  'spiral',
#  'transmit',
#  'languagesmysql',
#  'springboard',
#  'sorc',
#  'systemsadhere',
#  'productionengineeringmanager',
#  'tenering',
#  'solids',
#  'tradeoffs',
#  'networkable',
#  'servies',
#  'levers',
#  'worded',
#  'disregards',
#  'activites',
#  'goldmine',
#  'bourguignonne',
#  'designsensure',
#  'hese',
#  'talbots',
#  'conformation',
#  'barley',
#  'gasifiers',
#  'reproducing',
#  'appropriateto',
#  'assistantgeneralmanagernewopeningaberdeen',
#  'caresys',
#  'blocked',
#  'gamble',
#  'lamb',
#  'cdrl',
#  'llds',
#  'follower',
#  'oven',
#  'emphasise',
#  'chiamaka',
#  'hamiltonscarehomehotmail',
#  'competenciestechnical',
#  'serviceengineerfiresecuritynwyorkshire',
#  'appscan',
#  'starhotelrosetted',
#  'arms',
#  'inflate',
#  'incude',
#  'healthcaremedacs',
#  'robbins',
#  'castleford',
#  'formulaean',
#  'extensiongsa',
#  'orals',
#  'itchy',
#  'souschefcharacterfulpubwithbrandnewkitchenshareoftips',
#  'beeritnmark',
#  'convincing',
#  'altran',
#  'poke',
#  'poolside',
#  'anddevelopment',
#  'batching',
#  'timefinder',
#  'glycol',
#  'coolers',
#  'foreseeable',
#  'inspires',
#  'tsqlrecently',
#  'chiropody',
#  'fiddler',
#  'resolutionplanning',
#  'rrequired',
#  'capabilitiesexperience',
#  'benefitskey',
#  'eastlands',
#  'inducting',
#  'swxipad',
#  'prosody',
#  'meetingsdesign',
#  'opportunityan',
#  'rigsbill',
#  'draughtsmancontract',
#  'moral',
#  'violation',
#  'considers',
#  'dsear',
#  'cleanroom',
#  'replicated',
#  'halfwayjust',
#  'crashing',
#  'conversionrateoptimisationcromanager',
#  'maintenanceengineerdaysfoodindustry',
#  'outall',
#  'environmentallyaware',
#  'untrusted',
#  'withdraw',
#  'withsunrisecomplaints',
#  'allergies',
#  'commvault',
#  'mcfarlane',
#  'intervenes',
#  'helenjriverps',
#  'engender',
#  'residentialbased',
#  'juniorsouschefawardwinninghotelgoodcompanybenefits',
#  'staveley',
#  'chefdepartiecorporateledhotelallfreshfoodstraights',
#  'calendars',
#  'headchefawardwinningcountryinntopqualitydininglivein',
#  'communicationstrong',
#  'maintenanceteamleader',
#  'ultraviolet',
#  'acegi',
#  'chefdepartiewokingcentrefreshfoodbranded',
#  'prioritizationmanage',
#  'nessential',
#  'infocaffev',
#  'sculptured',
#  'spoons',
#  'landesk',
#  'buffets',
#  'alton',
#  'jqueryasp',
#  'moston',
#  'seniorsouschefhighendcountryhousehotelawardwinningdining',
#  'preffered',
#  'skull',
#  'fitzmaurice',
#  'confectionary',
#  'monthsstart',
#  'bowdon',
#  'sprits',
#  'scandia',
#  'crossfunctionally',
#  'lounges',
#  'trailers',
#  'shadows',
#  'guillotines',
#  'assistantmanagerbrilliantbrandedrestaurantnorthlondon',
#  'maintenanceelectrician',
#  'tredomen',
#  'itchens',
#  'ecrs',
#  'etcunderstanding',
#  'chefdepartiehighvolumeconferencecentreallfreshfood',
#  'bachelorpreferred',
#  'unqual',
#  'exterior',
#  'chefdepartiebusybrasseriestylerestaurantallfreshfood',
#  'privde',
#  'viruses',
#  'permenant',
#  'proii',
#  'recentlyopenedrestaurantchefdepartiefinedining',
#  'assumes',
#  'reportable',
#  'notwithstanding',
#  'adventure',
#  'downhole',
#  'seniorsurveyorssocialhousing',
#  'annuallyset',
#  'electricalcontrolsandcommissioningmanager',
#  'flooding',
#  'bolster',
#  'requirementsall',
#  'minuet',
#  'reaction',
#  'strengthened',
#  'mediaplex',
#  'rakesh',
#  'scottprecisionrecruitment',
#  'sprinkled',
#  'beneficialsenior',
#  'unforeseen',
#  'litigation',
#  'clamps',
#  'jessica',
#  'everevolving',
#  'expressing',
#  'irresistible',
#  'priceline',
#  'ceramics',
#  'elivery',
#  'smear',
#  'uncollectable',
#  'talentedchefdepartierequiredfor',
#  'programmingan',
#  'pakistani',
#  'unbudgeted',
#  'fashioned',
#  'inst',
#  'ontrack',
#  'resp',
#  'managerto',
#  'compressed',
#  'vulture',
#  'skillsconfident',
#  'sorted',
#  'rscs',
#  'anticipatory',
#  'stocksbridge',
#  'pigeon',
#  "leicester's",
#  'nbspyou',
#  'sturgesscompassltd',
#  'fazed',
#  'detiox',
#  'cation',
#  'clusterfinancialcontroller',
#  'cashing',
#  'vmstat',
#  'franck',
#  'distributionsstrong',
#  'developmentexperience',
#  'intellect',
#  'heidenhein',
#  'resuscitation',
#  'chefdepartiewellrespectedfoodfocusedhoteltipslivein',
#  'fullscale',
#  'plane',
#  'clientserver',
#  'refusals',
#  'homer',
#  'responsibilitiesmy',
#  'unicenter',
#  'bouygues',
#  'facilitiesmanagerfacilitiescoordinator',
#  'uptake',
#  'prewritten',
#  "vacancy's",
#  'isis',
#  'claimants',
#  'timelimited',
#  'neural',
#  'architectlevel',
#  'chefdepartielargehotelwantingtoimprovestandardslivein',
#  'wizardry',
#  "pqq's",
#  'programminggood',
#  'skillsadvanced',
#  'quantum',
#  'daytimes',
#  'headchefnewopeningaberdeen',
#  'allimportant',
#  'cmmiitilcobit',
#  'scans',
#  'merry',
#  'mechatronics',
#  'decomposition',
#  'bind',
#  'isirt',
#  'oproactively',
#  'staus',
#  'garages',
#  'psychiatry',
#  'succinctly',
#  'partierequired',
#  'furthered',
#  'fringe',
#  'burscough',
#  'haptic',
#  'reportscollaboratively',
#  'furnitureinstallationteamleader',
#  'sabbatical',
#  'microdisplay',
#  'nowto',
#  'helmsley',
#  'scoped',
#  'jobsexemplarhc',
#  'patternscandidates',
#  'sqlable',
#  'followers',
#  'stateofthe',
#  'patented',
#  'presume',
#  'gormanselectiongroup',
#  'refurbishments',
#  'etsi',
#  'subsuppliers',
#  'tyre',
#  'tendring',
#  'creditriskconsultant',
#  'autoloaders',
#  'vectorcast',
#  'snapview',
#  'multiskilledmaintenanceengineermechanicalbias',
#  'daylocation',
#  'midlarge',
#  "department's",
#  'restarant',
#  'blaby',
#  'multisited',
#  'copier',
#  'ambu',
#  'formers',
#  'areasappointment',
#  'shut',
#  'myessexbased',
#  'energeticthere',
#  'barnstapledevon',
#  'srdf',
#  'troubleshoottake',
#  'southendonsea',
#  'concordian',
#  "dealership's",
#  'productdesignengineer',
#  'patents',
#  'driers',
#  'persuades',
#  'alectorecruitment',
#  'technologya',
#  'metaframe',
#  'bathe',
#  'enrolments',
#  'glms',
#  'commischeftwoaarosettehotelweddingvenueliveintips',
#  'whiskas',
#  'rafiki',
#  'inprocess',
#  'teststo',
#  'requisitioned',
#  'outsoursing',
#  'stanley',
#  'faultfree',
#  'elect',
#  'socialn',
#  'apip',
#  'michel',
#  'thatcham',
#  'databased',
#  'marketled',
#  'souschefrestaurantbanquetinggrandyorkshirehotel',
#  'dormant',
#  'callmanager',
#  'fractures',
#  'traindevelop',
#  'liquidly',
#  'biddable',
#  'lansiquot',
#  'commischefrefurbishedrestaurantallfreshproduce',
#  'snags',
#  'torbay',
#  'cumbrian',
#  'rival',
#  'ratesd',
#  'faststream',
#  'areeither',
#  'bpas',
#  'malfunctioning',
#  'matlabcassemblerfpgaconsumer',
#  'banquetchefcountryhousehotelawardwinningvenuelivein',
#  'quotfoodie',
#  'brianclaremontconsulting',
#  'hurt',
#  'additives',
#  'pcidss',
#  'cmiia',
#  'heneghannovouk',
#  'abbishaw',
#  'regionalsalesmanager',
#  'dads',
#  'qualitatively',
#  'morpeth',
#  'wcdma',
#  'intertel',
#  'charlesworth',
#  'riseley',
#  'rows',
#  'chieftechnologyofficer',
#  'endorsement',
#  'betting',
#  'changean',
#  'beneath',
#  'cadmep',
#  'newspaper',
#  'alterafpga',
#  'addictions',
#  'harris',
#  'atributes',
#  'mailbox',
#  'farmers',
#  'ccse',
#  'primers',
#  'highlylisted',
#  'tpcp',
#  'mobberley',
#  'choise',
#  'converged',
#  'goole',
#  'featured',
#  'actionmonitor',
#  'cateys',
#  'selfimprovement',
#  'lindaprecedohealthcareco',
#  'honed',
#  'sitters',
#  'technicalmanagerheadofdevelopment',
#  'remittance',
#  'cure',
#  'alternating',
#  'developmentin',
#  'fetes',
#  'defstan',
#  'kookai',
#  'matchingthe',
#  'managementrequirements',
#  'occupant',
#  'filler',
#  'productmanagergeneratorsmotors',
#  'vrvs',
#  'mirrorview',
#  'dutie',
#  'datareport',
#  'yorkshires',
#  'lifeless',
#  'collaborately',
#  'medieval',
#  'assistantmanagertraditionalfishchipshopcentrallondon',
#  'resale',
#  'targetfocused',
#  'energized',
#  'eurocodes',
#  'aarosetteslivein',
#  'pragmatism',
#  'barristers',
#  'hadley',
#  'administrationoracle',
#  'declarations',
#  'retest',
#  'revaluation',
#  'stakeholdersexcellent',
#  'patternsexperience',
#  'toastmaster',
#  'maintenanceengineerdays',
#  'planningessential',
#  'pearce',
#  'doxford',
#  'preventing',
#  'candiate',
#  'andajax',
#  'disinfecting',
#  'wrekin',
#  'hifi',
#  'unblocking',
#  'transformationour',
#  'subtly',
#  'saver',
#  'yearsall',
#  'monthursday',
#  'grammatically',
#  'smiths',
#  'performant',
#  'workinprogress',
#  'recruting',
#  'reknowned',
#  'monfriday',
#  'fusions',
#  'requried',
#  'consulted',
#  'curricula',
#  'interpedently',
#  'spitting',
#  'perfomormance',
#  'beach',
#  'compet',
#  'assignmens',
#  'glmms',
#  'accmedicorglobal',
#  'miniumum',
#  'stooping',
#  'cider',
#  'meltham',
#  'remediate',
#  'seeaking',
#  'fieldexperience',
#  'knowleadge',
#  'taqa',
#  'onbudgetto',
#  'qjnwou',
#  'gigevision',
#  'dronfield',
#  "russia's",
#  'cfirst',
#  'shrewd',
#  'editions',
#  'asses',
#  'incentivising',
#  'joblocation',
#  'trkhb',
#  'defensives',
#  'whenrequired',
#  'oldest',
#  'thiswe',
#  'mondayfridayif',
#  'stocksfield',
#  'adams',
#  'railability',
#  'sixth',
#  'cvhays',
#  'chaffing',
#  'maintainers',
#  'qualityauditor',
#  'etchays',
#  'carters',
#  'pregnancies',
#  'florida',
#  'caitriona',
#  'seller',
#  'nominating',
#  'axecutive',
#  'apprehensive',
#  'sisgter',
#  'superstars',
#  'penelope',
#  'lighter',
#  'yorkshiresalary',
#  'designinterfacemanager',
#  'dotnetnuke',
#  'kardexes',
#  'galvanise',
#  'adjusters',
#  'exoffenders',
#  'zahidjustsocialcare',
#  'smiling',
#  'bestofbreed',
#  'socializing',
#  'macmillan',
#  'whichever',
#  'reproductive',
#  'vcentre',
#  'assmembly',
#  'employeecentric',
#  'culminates',
#  'expiry',
#  'crewing',
#  'materialsbuyer',
#  'webchat',
#  'trainingprofessional',
#  'discovering',
#  'portugal',
#  'throughs',
#  'preacceptance',
#  'ashby',
#  'pretrade',
#  'nonsalesly',
#  'ensured',
#  'swabs',
#  'pullers',
#  'directtoconsumer',
#  'flavoursome',
#  'jobnew',
#  'harbors',
#  'packed',
#  'economist',
#  'pulses',
#  'clapham',
#  'escenic',
#  'visuals',
#  'lennon',
#  'rigourous',
#  'erss',
#  'hangars',
#  'reminded',
#  'gesture',
#  'crockery',
#  'lamps',
#  'ultrahigh',
#  'egyptian',
#  'nooks',
#  'alinae',
#  'harding',
#  'chefdepartieaccreditedboutiquehotelshareoftips',
#  'reprographics',
#  'spearheaded',
#  'classed',
#  'intrusive',
#  'embraced',
#  'availablethe',
#  'extrovert',
#  'engineerkey',
#  'aiag',
#  'mealtimes',
#  'workscopes',
#  'applicationsoftwareengineer',
#  'afert',
#  'fullybookedrecruitment',
#  'extracttransformload',
#  'middleman',
#  'managerlondon',
#  'simplistic',
#  'maharahays',
#  'conway',
#  'sponsorships',
#  'experienceagile',
#  'interst',
#  'esol',
#  'dtcspecific',
#  'muck',
#  "norfolk's",
#  'religions',
#  'flies',
#  'manufacturingproductionengineerengineassembly',
#  'mouseover',
#  'touted',
#  "api's",
#  'cancel',
#  'falter',
#  'orthopedics',
#  'serveranddatacentreteamleaderdatacenterdatacentre',
#  'commischefoutstandingfinediningrestaurantservicecharge',
#  'dicsussions',
#  'emphasizing',
#  'semisolid',
#  'teama',
#  'componentsexperience',
#  'processingschematic',
#  'vicky',
#  'nicoise',
#  'maxilliofacial',
#  'gradual',
#  'dynamical',
#  'attendmandatory',
#  'imac',
#  'flint',
#  'thermocouples',
#  'remembering',
#  'caterpillar',
#  'dogs',
#  'jasonalphaconsultuae',
#  'baseprince',
#  'grocockrandstadfp',
#  'souschefsmallfreshfoodhotelongoingtrainingtemplivein',
#  'buoyant',
#  'jackets',
#  'multitalented',
#  'impede',
#  'distributes',
#  'breadboard',
#  'boardlevel',
#  'removals',
#  'theukwith',
#  'assistantspreferably',
#  'cleinets',
#  'sigmoidoscopy',
#  'judgemental',
#  'wlan',
#  'environmentthey',
#  'environmentsundertake',
#  'maximises',
#  'beccles',
#  'engagementaccountable',
#  'awfs',
#  'engineersalary',
#  'therapeutics',
#  'iplayer',
#  'showcasing',
#  'microsoftinternetexplorer',
#  'filton',
#  'wilcocks',
#  'nalthough',
#  'creationporting',
#  'underline',
#  'atii',
#  'qualitycontroller',
#  'superquickturn',
#  'segensworth',
#  'cotswolds',
#  'couchdb',
#  'ppcu',
#  'cherwell',
#  'starschema',
#  'limitwe',
#  'intapeople',
#  'retargeting',
#  'escapes',
#  'burley',
#  'developmentamoria',
#  'sweeping',
#  'valnerable',
#  'babbitt',
#  'isas',
#  'imaginatively',
#  'visualarts',
#  'lindsay',
#  'slight',
#  'fiver',
#  'intravenous',
#  'commisdemifreshhomemadefoodcountrypub',
#  'gscesa',
#  'improvementsfocussed',
#  'basingstokefor',
#  'enzyme',
#  'perceive',
#  'exporting',
#  'gounds',
#  'prismatic',
#  'thesouthcoast',
#  'capm',
#  'ktayloroctopusinvestments',
#  'ethereal',
#  'helm',
#  'javaspringdevelopersecommercedevelopmentnorthampton',
#  'deafness',
#  'eveloping',
#  'biometrics',
#  'hlsds',
#  'opulent',
#  'blackboard',
#  'innercity',
#  'passions',
#  'battery',
#  "testing'c",
#  'treble',
#  'pour',
#  'residences',
#  'baby',
#  'everify',
#  'steak',
#  'productapprovalsandlegislationengineer',
#  'recovered',
#  'spamanagerfamous',
#  'misdescriptions',
#  'opthalmology',
#  'entrepreneurialism',
#  'manderson',
#  'renewablesalary',
#  'extron',
#  'remodels',
#  'selfbetterment',
#  'levelheaded',
#  'sidamnvzgu',
#  'acsl',
#  'atleast',
#  'hometo',
#  'philip',
#  'simultaneouslynice',
#  'oddy',
#  'resited',
#  'alexander',
#  'testify',
#  'bestimproving',
#  'retrofits',
#  'waltham',
#  'anfd',
#  'soiled',
#  'strainstall',
#  'federal',
#  'nsitive',
#  'apachethis',
#  'pokeyoke',
#  'ukas',
#  'quothandson',
#  'scrumban',
#  "ssow's",
#  'aila',
#  'multiskilledmaintenanceengineer',
#  'appsens',
#  'brownfield',
#  'nbspmanufacturinglocation',
#  'demoing',
#  'bladesystems',
#  'davey',
#  'procuring',
#  'riskbased',
#  'purlieu',
#  'reminders',
#  'descriptionabout',
#  'justforthemoney',
#  'examining',
#  'champagne',
#  'risc',
#  'theukand',
#  'dippfs',
#  'inca',
#  'levelthe',
#  'romotions',
#  'accuratelyhays',
#  'allocations',
#  'databasedriven',
#  'multiregional',
#  'hyperactivity',
#  'infoactiveassistance',
#  'wagons',
#  'projectmanagerautomation',
#  'noetix',
#  'asbuilt',
#  'enthused',
#  'interpretative',
#  'experiencea',
#  'apimultithreaded',
#  'holden',
#  'oxidisers',
#  'stan',
#  'applicatiosn',
#  'toronto',
#  'rain',
#  'purposeto',
#  'acis',
#  'whizz',
#  'ericom',
#  'ccws',
#  'managementpresalessupporting',
#  'noneea',
#  'bytes',
#  'prequisite',
#  'winwick',
#  'particpate',
#  'sweep',
#  'recursion',
#  'accross',
#  "charity's",
#  'terma',
#  'conquer',
#  'otrs',
#  'sich',
#  'succeeded',
#  ...}

# %% [markdown]
# ### lowFreq.txt
# - Saving the sorted list of the words that appear only once in one job advertisement description to a file

# %%
out_file = open("lowFreq.txt", 'w')
for d in once_only:
    out_file.write(''.join(d) + '\n')
out_file.close()

# %%
# At this stage, I repead the same steps above
# However, this time the intention is to find the highFreq words
# start from removing lowFreq tokens from the list of tokens

tokenised = purifier(tokenised,once_only)

# %% [markdown]
# - Now, I'm going to create a new list of words after once_only words are removed

# %%
LowFreqRemoved_Words = list(chain.from_iterable([word for word in job] for job in tokenised))
LowFreqRemoved_vocab = set(LowFreqRemoved_Words)
LowFreqRemoved_fd = FreqDist(LowFreqRemoved_Words)

# %%
highFreq = set([k for k, v in LowFreqRemoved_fd.items() if v > 100])

# %% [markdown]
# ### highFreq.txt
# - Saving the sorted list of high frequent words that appear in more than 100 job advertisement description to a file

# %%
out_file = open("highFreq.txt", 'w')
for d in highFreq:
    out_file.write(''.join(d) + '\n')
out_file.close()

# %%
set(highFreq)
# Out:
# {'ability',
#  'accept',
#  'access',
#  'accommodation',
#  'accordance',
#  'account',
#  'accounting',
#  'accounts',
#  'accurate',
#  'achieve',
#  'achieving',
#  'acting',
#  'active',
#  'actively',
#  'activities',
#  'activity',
#  'acts',
#  'addition',
#  'additional',
#  'address',
#  'administration',
#  'adults',
#  'advanced',
#  'advantage',
#  'advantageous',
#  'advertised',
#  'advice',
#  'agencies',
#  'agency',
#  'agile',
#  'agreed',
#  'allowance',
#  'alongside',
#  'alternatively',
#  'ambitious',
#  'analysis',
#  'analyst',
#  'analytical',
#  'annual',
#  'annum',
#  'applicant',
#  'applicants',
#  'application',
#  'applications',
#  'apply',
#  'applying',
#  'appointments',
#  'approach',
#  'architecture',
#  'area',
#  'areas',
#  'arisen',
#  'asap',
#  'aspects',
#  'assess',
#  'assessment',
#  'assessments',
#  'assignments',
#  'assist',
#  'assistance',
#  'assistant',
#  'assistants',
#  'assisting',
#  'associates',
#  'assurance',
#  'asylum',
#  'attend',
#  'attention',
#  'attitude',
#  'attributes',
#  'audits',
#  'authority',
#  'automotive',
#  'availability',
#  'award',
#  'aware',
#  'awareness',
#  'back',
#  'background',
#  'bank',
#  'base',
#  'based',
#  'basic',
#  'basis',
#  'behalf',
#  'behaviour',
#  'beneficial',
#  'benefit',
#  'benefits',
#  'birmingham',
#  'bonus',
#  'brand',
#  'brown',
#  'budget',
#  'build',
#  'building',
#  'built',
#  'business',
#  'busy',
#  'button',
#  'call',
#  'calls',
#  'candidate',
#  'candidates',
#  'capable',
#  'capacity',
#  'care',
#  'career',
#  'carers',
#  'caring',
#  'carry',
#  'case',
#  'cases',
#  'caterer',
#  'catering',
#  'central',
#  'centre',
#  'challenge',
#  'challenging',
#  'chance',
#  'change',
#  'check',
#  'checks',
#  'chef',
#  'chefs',
#  'children',
#  'choice',
#  'circa',
#  'city',
#  'class',
#  'clean',
#  'clear',
#  'click',
#  'clicking',
#  'client',
#  'clients',
#  'clinical',
#  'close',
#  'closely',
#  'code',
#  'colleagues',
#  'comfortable',
#  'commercial',
#  'commission',
#  'commitment',
#  'committed',
#  'communicate',
#  'communication',
#  'communications',
#  'communicator',
#  'community',
#  'commutable',
#  'companies',
#  'company',
#  'competent',
#  'competitive',
#  'complete',
#  'completed',
#  'completion',
#  'complex',
#  'compliance',
#  'components',
#  'comprehensive',
#  'computer',
#  'conditions',
#  'conduct',
#  'confidence',
#  'confident',
#  'configuration',
#  'considered',
#  'consultancy',
#  'consultant',
#  'consultants',
#  'consulting',
#  'contact',
#  'contacted',
#  'continue',
#  'continued',
#  'continuous',
#  'contract',
#  'contracts',
#  'contribute',
#  'control',
#  'controls',
#  'cooking',
#  'copy',
#  'core',
#  'corporate',
#  'cost',
#  'country',
#  'cover',
#  'covering',
#  'create',
#  'creating',
#  'creative',
#  'criteria',
#  'critical',
#  'current',
#  'customer',
#  'customers',
#  'cycle',
#  'daily',
#  'data',
#  'database',
#  'date',
#  'days',
#  'deadlines',
#  'deal',
#  'dealing',
#  'decision',
#  'dedicated',
#  'degree',
#  'deliver',
#  'delivered',
#  'delivering',
#  'delivery',
#  'dementia',
#  'demonstrable',
#  'demonstrate',
#  'department',
#  'departments',
#  'dependent',
#  'depending',
#  'deputy',
#  'description',
#  'design',
#  'designing',
#  'designs',
#  'desirable',
#  'desire',
#  'detail',
#  'detailed',
#  'details',
#  'develop',
#  'developed',
#  'developer',
#  'developers',
#  'developing',
#  'development',
#  'difference',
#  'digital',
#  'dining',
#  'direct',
#  'direction',
#  'directly',
#  'director',
#  'disabilities',
#  'disability',
#  'discipline',
#  'disciplines',
#  'disclosure',
#  'discuss',
#  'diverse',
#  'division',
#  'document',
#  'documentation',
#  'documented',
#  'documents',
#  'domestic',
#  'drawings',
#  'drive',
#  'driven',
#  'driver',
#  'driving',
#  'duties',
#  'duty',
#  'dynamic',
#  'earn',
#  'east',
#  'easy',
#  'eclypse',
#  'eden',
#  'edge',
#  'educated',
#  'education',
#  'effective',
#  'effectively',
#  'efficient',
#  'elderly',
#  'electrical',
#  'eligibility',
#  'eligible',
#  'email',
#  'employee',
#  'employees',
#  'employer',
#  'employment',
#  'enable',
#  'energy',
#  'engineer',
#  'engineering',
#  'engineers',
#  'england',
#  'english',
#  'enhance',
#  'enhanced',
#  'enjoy',
#  'ensure',
#  'ensuring',
#  'enterprise',
#  'enthusiastic',
#  'environment',
#  'environments',
#  'equal',
#  'equality',
#  'equipment',
#  'equivalent',
#  'essential',
#  'establish',
#  'established',
#  'europe',
#  'evenings',
#  'events',
#  'evidence',
#  'excel',
#  'excellence',
#  'excellent',
#  'exceptional',
#  'exciting',
#  'executive',
#  'existing',
#  'expanding',
#  'expansion',
#  'expect',
#  'expectations',
#  'expected',
#  'experience',
#  'experienced',
#  'expert',
#  'expertise',
#  'exposure',
#  'extensive',
#  'external',
#  'facilities',
#  'facing',
#  'families',
#  'family',
#  'fantastic',
#  'fast',
#  'feedback',
#  'feel',
#  'field',
#  'finance',
#  'financial',
#  'find',
#  'finding',
#  'firm',
#  'flexibility',
#  'flexible',
#  'focus',
#  'focused',
#  'follow',
#  'food',
#  'form',
#  'forward',
#  'found',
#  'frail',
#  'framework',
#  'free',
#  'fresh',
#  'friday',
#  'friendly',
#  'full',
#  'fully',
#  'function',
#  'functional',
#  'functions',
#  'future',
#  'gain',
#  'gained',
#  'general',
#  'generation',
#  'generous',
#  'genuine',
#  'give',
#  'giving',
#  'global',
#  'goals',
#  'good',
#  'graduate',
#  'great',
#  'group',
#  'groups',
#  'grow',
#  'growing',
#  'growth',
#  'guidance',
#  'guidelines',
#  'handling',
#  'hands',
#  'happy',
#  'hard',
#  'hardware',
#  'head',
#  'health',
#  'healthcare',
#  'hear',
#  'held',
#  'helping',
#  'high',
#  'highest',
#  'highly',
#  'hold',
#  'holiday',
#  'holidays',
#  'home',
#  'homes',
#  'honest',
#  'hospital',
#  'hotel',
#  'hour',
#  'hourly',
#  'hours',
#  'house',
#  'html',
#  'ideal',
#  'ideally',
#  'ideas',
#  'identify',
#  'identifying',
#  'immediately',
#  'immigration',
#  'implement',
#  'implementation',
#  'implementing',
#  'important',
#  'improve',
#  'improvement',
#  'improvements',
#  'include',
#  'includes',
#  'including',
#  'increase',
#  'independence',
#  'independent',
#  'independently',
#  'individual',
#  'individuals',
#  'induction',
#  'industries',
#  'industry',
#  'information',
#  'infrastructure',
#  'initial',
#  'initiative',
#  'innovative',
#  'installation',
#  'insurance',
#  'integration',
#  'interest',
#  'interested',
#  'internal',
#  'international',
#  'interpersonal',
#  'interview',
#  'interviews',
#  'investment',
#  'involve',
#  'involved',
#  'issues',
#  'java',
#  'javascript',
#  'jobs',
#  'jobseeking',
#  'join',
#  'joining',
#  'junior',
#  'keen',
#  'keywords',
#  'kitchen',
#  'knowledge',
#  'language',
#  'large',
#  'largest',
#  'latest',
#  'lead',
#  'leader',
#  'leadership',
#  'leading',
#  'leads',
#  'learn',
#  'learning',
#  'legislation',
#  'leisure',
#  'letter',
#  'level',
#  'levels',
#  'liaise',
#  'liaising',
#  'liaison',
#  'licence',
#  'life',
#  'lifecycle',
#  'limited',
#  'line',
#  'linux',
#  'literate',
#  'live',
#  'living',
#  'local',
#  'located',
#  'location',
#  'locations',
#  'london',
#  'long',
#  'love',
#  'made',
#  'main',
#  'maintain',
#  'maintained',
#  'maintaining',
#  'maintenance',
#  'major',
#  'make',
#  'making',
#  'manage',
#  'managed',
#  'management',
#  'manager',
#  'managers',
#  'managing',
#  'manchester',
#  'manner',
#  'manufacturing',
#  'market',
#  'marketing',
#  'markets',
#  'match',
#  'matches',
#  'meals',
#  'mechanical',
#  'media',
#  'medical',
#  'medication',
#  'medium',
#  'meet',
#  'meeting',
#  'meetings',
#  'member',
#  'members',
#  'mental',
#  'microsoft',
#  'midlands',
#  'minimum',
#  'mobile',
#  'modern',
#  'monday',
#  'money',
#  'monitor',
#  'monitoring',
#  'month',
#  'monthly',
#  'months',
#  'motivate',
#  'motivated',
#  'move',
#  'multi',
#  'multidisciplinary',
#  'multiple',
#  'national',
#  'nature',
#  'needed',
#  'negotiable',
#  'network',
#  'networking',
#  'newly',
#  'night',
#  'nights',
#  'north',
#  'note',
#  'notice',
#  'number',
#  'nurse',
#  'nurses',
#  'nursing',
#  'objectives',
#  'offer',
#  'offered',
#  'offering',
#  'offers',
#  'office',
#  'offices',
#  'ongoing',
#  'online',
#  'open',
#  'opening',
#  'operate',
#  'operates',
#  'operating',
#  'operation',
#  'operational',
#  'operations',
#  'opportunities',
#  'opportunity',
#  'order',
#  'organisation',
#  'organisational',
#  'organisations',
#  'organised',
#  'originally',
#  'outstanding',
#  'overtime',
#  'paced',
#  'package',
#  'packages',
#  'paid',
#  'part',
#  'participate',
#  'partie',
#  'partners',
#  'passion',
#  'passionate',
#  'patient',
#  'patients',
#  'pattern',
#  'patterns',
#  'pension',
#  'people',
#  'perform',
#  'performance',
#  'period',
#  'permanent',
#  'person',
#  'personal',
#  'personnel',
#  'phone',
#  'physical',
#  'place',
#  'plan',
#  'planned',
#  'planning',
#  'plans',
#  'plant',
#  'player',
#  'point',
#  'policies',
#  'policy',
#  'portfolio',
#  'position',
#  'positions',
#  'positive',
#  'possess',
#  'post',
#  'posted',
#  'potential',
#  'pound',
#  'practical',
#  'practice',
#  'practices',
#  'preferably',
#  'preferred',
#  'preparation',
#  'prepare',
#  'prepared',
#  'preparing',
#  'present',
#  'presentation',
#  'pressure',
#  'prestigious',
#  'previous',
#  'primary',
#  'principles',
#  'prior',
#  'privacy',
#  'private',
#  'proactive',
#  'problem',
#  'problems',
#  'procedures',
#  'process',
#  'processes',
#  'processing',
#  'produce',
#  'producing',
#  'product',
#  'production',
#  'products',
#  'professional',
#  'professionals',
#  'profile',
#  'programme',
#  'programmes',
#  'programming',
#  'progress',
#  'progression',
#  'progressive',
#  'project',
#  'projects',
#  'promote',
#  'promoting',
#  'property',
#  'prospects',
#  'protection',
#  'proven',
#  'provide',
#  'provided',
#  'provider',
#  'providers',
#  'providing',
#  'provision',
#  'public',
#  'purpose',
#  'qualification',
#  'qualifications',
#  'qualified',
#  'quality',
#  'queries',
#  'quickly',
#  'range',
#  'rapidly',
#  'rate',
#  'rates',
#  'real',
#  'receive',
#  'receiving',
#  'recent',
#  'recognised',
#  'recommend',
#  'record',
#  'records',
#  'recruit',
#  'recruiting',
#  'recruitment',
#  'reference',
#  'references',
#  'region',
#  'registered',
#  'registration',
#  'regular',
#  'regulations',
#  'regulatory',
#  'related',
#  'relation',
#  'relationship',
#  'relationships',
#  'relevant',
#  'reliable',
#  'report',
#  'reporting',
#  'reports',
#  'reputable',
#  'reputation',
#  'requested',
#  'require',
#  'required',
#  'requirement',
#  'requirements',
#  'requires',
#  'research',
#  'residential',
#  'residents',
#  'resources',
#  'respond',
#  'response',
#  'responsibilities',
#  'responsibility',
#  'responsible',
#  'restaurant',
#  'results',
#  'retail',
#  'return',
#  'review',
#  'reviews',
#  'rewarding',
#  'risk',
#  'role',
#  'roles',
#  'rosette',
#  'rota',
#  'running',
#  'safe',
#  'safeguarding',
#  'safety',
#  'salary',
#  'sales',
#  'satisfaction',
#  'scheme',
#  'schemes',
#  'school',
#  'schools',
#  'search',
#  'section',
#  'sector',
#  'sectors',
#  'secure',
#  'security',
#  'seeking',
#  'selection',
#  'selling',
#  'send',
#  'sending',
#  'senior',
#  'server',
#  'service',
#  'services',
#  'setting',
#  'share',
#  'shift',
#  'shifts',
#  'short',
#  'significant',
#  'similar',
#  'site',
#  'sites',
#  'situated',
#  'sized',
#  'skill',
#  'skilled',
#  'skills',
#  'small',
#  'smooth',
#  'social',
#  'software',
#  'solid',
#  'solution',
#  'solutions',
#  'solving',
#  'sound',
#  'south',
#  'specialist',
#  'specific',
#  'specifically',
#  'specification',
#  'specifications',
#  'staff',
#  'stage',
#  'stakeholders',
#  'standard',
#  'standards',
#  'star',
#  'start',
#  'starting',
#  'status',
#  'step',
#  'strategic',
#  'strategies',
#  'strategy',
#  'strong',
#  'structure',
#  'structured',
#  'subject',
#  'succeed',
#  'success',
#  'successful',
#  'suit',
#  'suitable',
#  'supervision',
#  'supervisory',
#  'supplier',
#  'suppliers',
#  'supply',
#  'support',
#  'supported',
#  'supporting',
#  'supportive',
#  'surrey',
#  'surrounding',
#  'system',
#  'systems',
#  'taking',
#  'talented',
#  'target',
#  'targets',
#  'tasks',
#  'teacher',
#  'teachers',
#  'teaching',
#  'team',
#  'teams',
#  'technical',
#  'technically',
#  'technician',
#  'techniques',
#  'technologies',
#  'technology',
#  'telephone',
#  'temporary',
#  'term',
#  'terms',
#  'test',
#  'testing',
#  'thinking',
#  'time',
#  'timely',
#  'times',
#  'title',
#  'today',
#  'tools',
#  'totaljobs',
#  'touch',
#  'track',
#  'train',
#  'trained',
#  'training',
#  'transport',
#  'travel',
#  'treatment',
#  'type',
#  "uk's",
#  'understand',
#  'understanding',
#  'undertake',
#  'undertaking',
#  'uniform',
#  'unique',
#  'unit',
#  'unsuccessful',
#  'urgently',
#  'user',
#  'users',
#  'vacancies',
#  'vacancy',
#  'valid',
#  'varied',
#  'variety',
#  'vehicle',
#  'verbal',
#  'view',
#  'visit',
#  'visits',
#  'volume',
#  'website',
#  'week',
#  'weekend',
#  'weekends',
#  'weekly',
#  'weeks',
#  'west',
#  'whilst',
#  'white',
#  'wide',
#  'willingness',
#  'windows',
#  'winning',
#  'word',
#  'work',
#  'worked',
#  'worker',
#  'workers',
#  'working',
#  'workload',
#  'workplace',
#  'works',
#  'world',
#  'writing',
#  'written',
#  'year',
#  'years',
#  'yorkshire',
#  'young'}

# %%
# running the purifier funtion to remove highFreq tokens
tokenised = purifier(tokenised,highFreq)

# %% [markdown]
# - Now, I'm going to create a new list of words after highFreq words are removed

# %%
HighFreqRemoved_words = list(chain.from_iterable([word for word in job] for job in tokenised))
HighFreqRemoved_vocab = set(HighFreqRemoved_words)

# %% [markdown]
# ** This is an extra checkpoint to monitor the progress of purification

# %%
print(f"Length of words: {len(stop_wrds_removed_words)}")
print(f"Length of vocab: {len(stop_wrds_removed_vocab)}")
print(f"Length of LowFreqRemoved_Words: {len(LowFreqRemoved_Words)}")
print(f"Length of LowFreqRemoved_vocab: {len(LowFreqRemoved_vocab)}")
print(f"Length of HighFreqRemoved_words: {len(HighFreqRemoved_words)}")
print(f"Length of HighFreqRemoved_vocab: {len(HighFreqRemoved_vocab)}")
# Out:
# Length of words: 474345
# Length of vocab: 18619
# Length of LowFreqRemoved_Words: 465779
# Length of LowFreqRemoved_vocab: 10053
# Length of HighFreqRemoved_words: 126491
# Length of HighFreqRemoved_vocab: 9103

# %% [markdown]
# ### vocab.txt

# %%
HighFreqRemoved_vocab = list(HighFreqRemoved_vocab)

# %%
# list of final vocabs
vocab = {HighFreqRemoved_vocab[i]:i for i in range(0,len(HighFreqRemoved_vocab))}

# %%
# building a function to create th vocab.txt file meeting the task's requirements
def vaocab_output(file):
    with open (file, "a") as f:
        for key in sorted(vocab.keys()):
            f.write("%s:%s\n" % (key, vocab[key]))

# %%
# calling the function and build the file
vaocab_output("vocab.txt")

# %% [markdown]
# ### Parser.txt
#
# - Since I took on this task in the end, I realised all previous steps were included in this one as well.
# - As a result, I structured the whole code in a new format.
# - At this stage, I had a better understanding of the assessment requirement. So I structured the need more neetly.

# %%
data = {}
id = None
with open('data.txt', 'r',encoding="utf8") as f:
    for i, line in enumerate(f): # create the iteration in the range of imported file's length
        line = line.lower() 
        line = line.strip()
        if not line:
            continue
        section = line.split(':')[0] # define 'section' as a method to manupilate each line based on how the line begins
        content = ':'.join(line.split(':')[1:]).strip() # define 'content' a method to capture tokens
        if section == 'id': # id section:
            if id: # Error handle if theres some bad formatting: multiple ids
                raise ValueError('unable to parse file at line %d, multiple ids' % i)
            id = content[1:] # capture the job id
            if id in data.keys():# Error handle if theres some bad formatting: duplicates
                raise ValueError('unable to parse file at line %d, duplicate id' % i)
        elif section == 'description': #capture job description per each job ad
            if not id:# Error handle if theres some bad formatting: missing id
                raise ValueError('unable to parse file at line %d, missing id' % i)
            content = pattern.findall(line)
            content = [value for value in content if len(value) > 3] # remove short character token
            content = [value for value in content if value not in stopwordsset] # remove stopwords
            content = [value for value in content if value not in once_only] # remove lowFreq token
            content = [value for value in content if value not in highFreq] # remove highFreq tokens
            data[id] = content # creates data dictionary
            id = None
        elif section == 'title': # if the line start with 'title' do nothing
            continue
        else:
            raise ValueError('unable to parse file at line %d, unexpected section name' % i)

# %%
# Build output file:

with open('sparse.txt',"w") as f:
    for jobID,content in data.items(): # go through data dictionary created in the last block
        fd_parse = FreqDist(content) # count number of times each token occured in the same job ad
        tmp = "" # create a placeholder for word_index:word_freq
        for (x,y) in fd_parse.items(): # iterate through each frequencies
            tmp += f"{vocab[x]}:{y}," # build the dictionary of word_index:word_freq in the placeholder
        f.write(f"{jobID},{tmp[:-1]}\n") # write in the file line by line

# %% [markdown]
# ---end---
