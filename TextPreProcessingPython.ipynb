# %% [markdown]
#     Maziar Izadi - Data Scientist
#
#     Data wrangling in Python
#
# https://github.com/maziarizadi
#
# https://medium.com/@maziarizadi

# %%
# Import required libraries

# Regular Expressions (REGeX)
import re
from nltk.probability import *

# Natural Language Toolkit
import nltk

# Functions creating iterators for efficient looping
import itertools
from itertools import chain
from itertools import groupby

# Convert a collection of text documents to a matrix of token counts
from sklearn.feature_extraction.text import CountVectorizer

# %%
# open the file and read the contents
data = []

# make sure you define the encoding format otherwise you might get this error: 
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 260893: character maps to <undefined>
with open('data.txt', encoding="utf8") as f:
    data = f.read().lower() # read the content and lower the letters (for consistency)

# %%
# make a pattern for REGEX to find and keep matching words only
pattern = re.compile(r"[a-zA-Z]+(?:[-'][a-zA-Z]+)?") 

# tokenise the words: match the pattern to file's content and tokenize the content
tokenised = pattern.findall(data)

# %%
tokenised
# Out:
# ['id',
#  'title',
#  'engineering',
#  'systems',
#  'analyst',
#  'description',
#  'engineering',
#  'systems',
#  'analyst',
#  'dorking',
#  'surrey',
#  'salary',
#  'k',
#  'our',
#  'client',
#  'is',
#  'located',
#  'in',
#  'dorking',
#  'surrey',
#  'and',
#  'are',
#  'looking',
#  'for',
#  'engineering',
#  'systems',
#  'analyst',
#  'our',
#  'client',
#  'provides',
#  'specialist',
#  'software',
#  'development',
#  'keywords',
#  'mathematical',
#  'modelling',
#  'risk',
#  'analysis',
#  'system',
#  'modelling',
#  'optimisation',
#  'miser',
#  'pioneeer',
#  'engineering',
#  'systems',
#  'analyst',
#  'dorking',
#  'surrey',
#  'salary',
#  'k',
#  'id',
#  'title',
#  'stress',
#  'engineer',
#  'glasgow',
#  'description',
#  'stress',
#  'engineer',
#  'glasgow',
#  'salary',
#  'to',
#  'we',
#  're',
#  'currently',
#  'looking',
#  'for',
#  'talented',
#  'engineers',
#  'to',
#  'join',
#  'our',
#  'growing',
#  'glasgow',
#  'team',
#  'at',
#  'a',
#  'variety',
#  'of',
#  'levels',
#  'the',
#  'roles',
#  'are',
#  'ideally',
#  'suited',
#  'to',
#  'high',
#  'calibre',
#  'engineering',
#  'graduates',
#  'with',
#  'any',
#  'level',
#  'of',
#  'appropriate',
#  'experience',
#  'so',
#  'that',
#  'we',
#  'can',
#  'give',
#  'you',
#  'the',
#  'opportunity',
#  'to',
#  'use',
#  'your',
#  'technical',
#  'skills',
#  'to',
#  'provide',
#  'high',
#  'quality',
#  'input',
#  'to',
#  'our',
#  'aerospace',
#  'projects',
#  'spanning',
#  'both',
#  'aerostructures',
#  'and',
#  'aeroengines',
#  'in',
#  'return',
#  'you',
#  'can',
#  'expect',
#  'good',
#  'career',
#  'opportunities',
#  'and',
#  'the',
#  'chance',
#  'for',
#  'advancement',
#  'and',
#  'personal',
#  'and',
#  'professional',
#  'development',
#  'support',
#  'while',
#  'you',
#  'gain',
#  'chartership',
#  'and',
#  'some',
#  'opportunities',
#  'to',
#  'possibly',
#  'travel',
#  'or',
#  'work',
#  'in',
#  'other',
#  'offices',
#  'in',
#  'or',
#  'outside',
#  'of',
#  'the',
#  'uk',
#  'the',
#  'requirements',
#  'you',
#  'will',
#  'need',
#  'to',
#  'have',
#  'a',
#  'good',
#  'engineering',
#  'degree',
#  'that',
#  'includes',
#  'structural',
#  'analysis',
#  'such',
#  'as',
#  'aeronautical',
#  'mechanical',
#  'automotive',
#  'civil',
#  'with',
#  'some',
#  'experience',
#  'in',
#  'a',
#  'professional',
#  'engineering',
#  'environment',
#  'relevant',
#  'to',
#  'but',
#  'not',
#  'limited',
#  'to',
#  'the',
#  'aerospace',
#  'sector',
#  'you',
#  'will',
#  'need',
#  'to',
#  'demonstrate',
#  'experience',
#  'in',
#  'at',
#  'least',
#  'one',
#  'or',
#  'more',
#  'of',
#  'the',
#  'following',
#  'areas',
#  'structural',
#  'stress',
#  'analysis',
#  'composite',
#  'stress',
#  'analysis',
#  'any',
#  'industry',
#  'linear',
#  'and',
#  'nonlinear',
#  'finite',
#  'element',
#  'analysis',
#  'fatigue',
#  'and',
#  'damage',
#  'tolerance',
#  'structural',
#  'dynamics',
#  'thermal',
#  'analysis',
#  'aerostructures',
#  'experience',
#  'you',
#  'will',
#  'also',
#  'be',
#  'expected',
#  'to',
#  'demonstrate',
#  'the',
#  'following',
#  'qualities',
#  'a',
#  'strong',
#  'desire',
#  'to',
#  'progress',
#  'quickly',
#  'to',
#  'a',
#  'position',
#  'of',
#  'leadership',
#  'professional',
#  'approach',
#  'strong',
#  'communication',
#  'skills',
#  'written',
#  'and',
#  'verbal',
#  'commercial',
#  'awareness',
#  'team',
#  'working',
#  'being',
#  'comfortable',
#  'working',
#  'in',
#  'international',
#  'teams',
#  'and',
#  'self',
#  'managing',
#  'please',
#  'note',
#  'security',
#  'clearance',
#  'is',
#  'required',
#  'for',
#  'this',
#  'role',
#  'stress',
#  'engineer',
#  'glasgow',
#  'salary',
#  'to',
#  'id',
#  'title',
#  'modelling',
#  'and',
#  'simulation',
#  'analyst',
#  'description',
#  'mathematical',
#  'modeller',
#  'simulation',
#  'analyst',
#  'operational',
#  'analyst',
#  'basingstoke',
#  'hampshire',
#  'up',
#  'to',
#  'k',
#  'aae',
#  'pension',
#  'contribution',
#  'private',
#  'medical',
#  'and',
#  'dental',
#  'the',
#  'opportunity',
#  'our',
#  'client',
#  'is',
#  'an',
#  'independent',
#  'consultancy',
#  'firm',
#  'which',
#  'has',
#  'an',
#  'opportunity',
#  'for',
#  'a',
#  'data',
#  'analyst',
#  'with',
#  'years',
#  'experience',
#  'the',
#  'role',
#  'will',
#  'require',
#  'the',
#  'successful',
#  'candidate',
#  'to',
#  'demonstrate',
#  'their',
#  'ability',
#  'to',
#  'analyse',
#  'a',
#  'problem',
#  'and',
#  'arrive',
#  'at',
#  'a',
#  'solution',
#  'with',
#  'varying',
#  'levels',
#  'of',
#  'data',
#  'being',
#  'available',
#  'essential',
#  'skills',
#  'thorough',
#  'knowledge',
#  'of',
#  'excel',
#  'and',
#  'proven',
#  'ability',
#  'to',
#  'utilise',
#  'this',
#  'to',
#  'create',
#  'powerful',
#  'decision',
#  'support',
#  'models',
#  'experience',
#  'in',
#  'modelling',
#  'and',
#  'simulation',
#  'techniques',
#  'experience',
#  'of',
#  'techniques',
#  'such',
#  'as',
#  'discrete',
#  'event',
#  'simulation',
#  'and',
#  'or',
#  'sd',
#  'modelling',
#  'mathematical',
#  'scientific',
#  'background',
#  'minimum',
#  'degree',
#  'qualified',
#  'proven',
#  'analytical',
#  'and',
#  'problem',
#  'solving',
#  'skills',
#  'self',
#  'starter',
#  'ability',
#  'to',
#  'develop',
#  'solid',
#  'working',
#  'relationships',
#  'in',
#  'addition',
#  'to',
#  'formal',
#  'qualifications',
#  'and',
#  'experience',
#  'the',
#  'successful',
#  'candidate',
#  'will',
#  'require',
#  'excellent',
#  'written',
#  'and',
#  'verbal',
#  'communication',
#  'skills',
#  'be',
#  'energetic',
#  'enterprising',
#  'and',
#  'have',
#  'a',
#  'determination',
#  'to',
#  'succeed',
#  'they',
#  'will',
#  'be',
#  'required',
#  'to',
#  'build',
#  'solid',
#  'working',
#  'relationships',
#  'both',
#  'internally',
#  'with',
#  'colleagues',
#  'and',
#  'most',
#  'importantly',
#  'externally',
#  'with',
#  'our',
#  'clients',
#  'they',
#  'must',
#  'be',
#  'comfortable',
#  'working',
#  'independently',
#  'to',
#  'deliver',
#  'against',
#  'challenging',
#  'client',
#  'demands',
#  'the',
#  'offices',
#  'are',
#  'located',
#  'in',
#  'basingstoke',
#  'hampshire',
#  'but',
#  'our',
#  'client',
#  'work',
#  'for',
#  'clients',
#  'worldwide',
#  'the',
#  'successful',
#  'candidate',
#  'must',
#  'therefore',
#  'be',
#  'prepared',
#  'to',
#  'undertake',
#  'work',
#  'at',
#  'client',
#  'sites',
#  'for',
#  'short',
#  'periods',
#  'of',
#  'time',
#  'physics',
#  'mathematics',
#  'modelling',
#  'simulation',
#  'analytical',
#  'operational',
#  'research',
#  'mathematical',
#  'modelling',
#  'mathematical',
#  'modeller',
#  'simulation',
#  'analyst',
#  'operational',
#  'analyst',
#  'basingstoke',
#  'hampshire',
#  'k',
#  'aae',
#  'pension',
#  'contribution',
#  'private',
#  'medical',
#  'and',
#  'dental',
#  'id',
#  'title',
#  'engineering',
#  'systems',
#  'analyst',
#  'mathematical',
#  'modeller',
#  'description',
#  'engineering',
#  'systems',
#  'analyst',
#  'mathematical',
#  'modeller',
#  'our',
#  'client',
#  'is',
#  'a',
#  'highly',
#  'successful',
#  'and',
#  'respected',
#  'consultancy',
#  'providing',
#  'specialist',
#  'software',
#  'development',
#  'miser',
#  'pioneer',
#  'maths',
#  'mathematical',
#  'optimisation',
#  'risk',
#  'analysis',
#  'asset',
#  'management',
#  'water',
#  'industry',
#  'access',
#  'excel',
#  'vba',
#  'sql',
#  'systems',
#  'engineering',
#  'systems',
#  'analyst',
#  'mathematical',
#  'modeller',
#  'salary',
#  'k',
#  'k',
#  'negotiable',
#  'location',
#  'dorking',
#  'surrey',
#  'id',
#  'title',
#  'pioneer',
#  'miser',
#  'engineering',
#  'systems',
#  'analyst',
#  'description',
#  'pioneer',
#  'miser',
#  'engineering',
#  'systems',
#  'analyst',
#  'dorking',
#  'surrey',
#  'salary',
#  'k',
#  'located',
#  'in',
#  'surrey',
#  'our',
#  'client',
#  'provides',
#  'specialist',
#  'software',
#  'development',
#  'pioneer',
#  'miser',
#  'engineering',
#  'systems',
#  'analyst',
#  'dorking',
#  'surrey',
#  'salary',
#  'k',
#  'id',
#  'title',
#  'trainee',
#  'mortgage',
#  'advisor',
#  'east',
#  'midlands',
#  'description',
#  'are',
#  'you',
#  'a',
#  'successful',
#  'results',
#  'driven',
#  'person',
#  'are',
#  'you',
#  'looking',
#  'to',
#  'start',
#  'a',
#  'career',
#  'in',
#  'financial',
#  'services',
#  'are',
#  'you',
#  'looking',
#  'for',
#  'a',
#  'fast',
#  'paced',
#  'dynamic',
#  'working',
#  'environment',
#  'our',
#  'client',
#  'is',
#  'proud',
#  'to',
#  'be',
#  'an',
#  'independent',
#  'estate',
#  'agent',
#  'with',
#  'an',
#  'unbeatable',
#  'local',
#  'knowledge',
#  'and',
#  'reputation',
#  'for',
#  'excellent',
#  'service',
#  'they',
#  'have',
#  'a',
#  'mortgage',
#  'advisor',
#  'within',
#  'each',
#  'of',
#  'their',
#  'branches',
#  'to',
#  'accommodate',
#  'their',
#  'customer',
#  's',
#  'needs',
#  'as',
#  'a',
#  'trainee',
#  'mortgage',
#  'advisor',
#  'you',
#  'will',
#  'work',
#  'closely',
#  'with',
#  'your',
#  'team',
#  'to',
#  'learn',
#  'and',
#  'develop',
#  'whilst',
#  'achieving',
#  'shared',
#  'goals',
#  'in',
#  'addition',
#  'to',
#  'this',
#  'you',
#  'will',
#  'have',
#  'the',
#  'determination',
#  'to',
#  'succeed',
#  'in',
#  'the',
#  'financial',
#  'services',
#  'market',
#  'you',
#  'will',
#  'be',
#  'capable',
#  'of',
#  'working',
#  'effectively',
#  'under',
#  'pressure',
#  'and',
#  'in',
#  'a',
#  'target',
#  'orientated',
#  'environment',
#  'you',
#  'will',
#  'have',
#  'the',
#  'ability',
#  'to',
#  'successfully',
#  'achieve',
#  'your',
#  'cemap',
#  'qualifications',
#  'you',
#  'will',
#  'be',
#  'able',
#  'to',
#  'evaluate',
#  'business',
#  'at',
#  'every',
#  'opportunity',
#  'the',
#  'company',
#  'will',
#  'offer',
#  'a',
#  'fantastic',
#  'training',
#  'programme',
#  'as',
#  'well',
#  'as',
#  'full',
#  'funding',
#  'for',
#  'cemap',
#  'qualifications',
#  'all',
#  'within',
#  'a',
#  'supportive',
#  'team',
#  'working',
#  'environment',
#  'once',
#  'fully',
#  'qualified',
#  'achievable',
#  'progression',
#  'thresholds',
#  'are',
#  'put',
#  'in',
#  'place',
#  'with',
#  'excellent',
#  'earning',
#  'potential',
#  'with',
#  'a',
#  'track',
#  'record',
#  'of',
#  'successful',
#  'sales',
#  'abilities',
#  'preferably',
#  'within',
#  'an',
#  'estate',
#  'agency',
#  'setting',
#  'suitable',
#  'candidates',
#  'will',
#  'have',
#  'a',
#  'drive',
#  'and',
#  'enthusiasm',
#  'to',
#  'work',
#  'within',
#  'the',
#  'financial',
#  'services',
#  'market',
#  'the',
#  'ability',
#  'to',
#  'qualify',
#  'applicants',
#  'to',
#  'advise',
#  'on',
#  'their',
#  'purchasing',
#  'abilities',
#  'excellent',
#  'communication',
#  'skills',
#  'a',
#  'professional',
#  'and',
#  'friendly',
#  'approach',
#  'refined',
#  'numerate',
#  'abilities',
#  'and',
#  'an',
#  'attention',
#  'to',
#  'detail',
#  'a',
#  'driving',
#  'licence',
#  'own',
#  'car',
#  'excellent',
#  'computing',
#  'skills',
#  'you',
#  'must',
#  'be',
#  'a',
#  'self',
#  'motivated',
#  'driven',
#  'individual',
#  'with',
#  'the',
#  'ability',
#  'to',
#  'be',
#  'proactive',
#  'with',
#  'your',
#  'own',
#  'learning',
#  'and',
#  'development',
#  'you',
#  'will',
#  'have',
#  'the',
#  'ability',
#  'to',
#  'work',
#  'successfully',
#  'within',
#  'a',
#  'team',
#  'whilst',
#  'managing',
#  'your',
#  'own',
#  'individual',
#  'work',
#  'load',
#  'organisational',
#  'skills',
#  'and',
#  'a',
#  'will',
#  'to',
#  'succeed',
#  'are',
#  'also',
#  'a',
#  'must',
#  'belper',
#  'ilkeston',
#  'eastwood',
#  'derby',
#  'leicester',
#  'mansfield',
#  'melbourne',
#  'ripley',
#  'id',
#  'title',
#  'project',
#  'engineer',
#  'pharmaceutical',
#  'description',
#  'project',
#  'engineer',
#  'phamaceutical',
#  'c',
#  'excellent',
#  'benefits',
#  'oxfordshire',
#  'mg',
#  'project',
#  'engineer',
#  'job',
#  'role',
#  'responsible',
#  'for',
#  'execution',
#  'of',
#  'continuous',
#  'improvement',
#  'and',
#  'compliance',
#  'projects',
#  'responsible',
#  'too',
#  'for',
#  'subprojects',
#  'related',
#  'to',
#  'introduction',
#  'of',
#  'new',
#  'products',
#  'and',
#  'processes',
#  'in',
#  'order',
#  'to',
#  'meet',
#  'strategic',
#  'business',
#  'plans',
#  'the',
#  'position',
#  'is',
#  'jointly',
#  'responsible',
#  'fo',
#  'reporting',
#  'of',
#  'designated',
#  'capital',
#  'and',
#  'expenses',
#  'actual',
#  'vs',
#  'plan',
#  'associated',
#  'with',
#  'implementation',
#  'of',
#  'new',
#  'process',
#  'equipment',
#  'or',
#  'modifications',
#  ...]

# %%
# pass the length of the 'tokenised' series into a variable
tokenised_len = len(tokenised)

# indexing the tokens based on the position of "id" and "title"
indexes = [i for i, v in enumerate(tokenised) if v=='id' and i+1 < tokenised_len and tokenised[i+1]=='title']

# %%
indexes
# Out:
# [0,
#  50,
#  296,
#  540,
#  594,
#  629,
#  930,
#  1089,
#  1352,
#  1664,
#  1953,
#  1984,
#  2107,
#  2339,
#  2653,
#  2972,
#  3261,
#  3770,
#  4257,
#  4606,
#  5038,
#  5353,
#  5563,
#  5806,
#  5917,
#  6044,
#  6258,
#  6628,
#  6986,
#  7141,
#  7272,
#  7678,
#  7803,
#  8175,
#  8411,
#  9008,
#  9166,
#  9405,
#  9603,
#  9890,
#  10153,
#  10542,
#  10666,
#  10955,
#  11227,
#  11655,
#  12092,
#  12353,
#  12872,
#  13277,
#  13529,
#  13793,
#  13874,
#  14329,
#  14694,
#  15095,
#  15383,
#  15789,
#  15958,
#  16422,
#  16613,
#  16848,
#  17093,
#  17353,
#  17622,
#  18015,
#  18419,
#  18556,
#  18648,
#  18732,
#  18973,
#  19930,
#  20197,
#  20425,
#  20805,
#  21080,
#  21325,
#  21481,
#  21700,
#  21972,
#  22173,
#  22434,
#  22812,
#  23088,
#  23350,
#  23595,
#  23878,
#  24139,
#  24291,
#  24445,
#  24596,
#  24977,
#  25245,
#  25477,
#  25571,
#  25691,
#  26155,
#  26376,
#  26672,
#  26907,
#  27301,
#  27497,
#  27566,
#  27623,
#  27684,
#  27783,
#  27897,
#  28146,
#  28493,
#  28813,
#  28975,
#  29211,
#  29513,
#  29720,
#  29940,
#  30001,
#  30092,
#  30517,
#  30725,
#  31012,
#  31338,
#  31477,
#  31843,
#  31930,
#  32079,
#  32197,
#  32316,
#  32518,
#  32720,
#  32918,
#  33095,
#  33294,
#  33403,
#  33528,
#  33628,
#  33741,
#  33883,
#  34068,
#  34205,
#  34358,
#  34664,
#  34887,
#  35135,
#  35212,
#  35313,
#  35706,
#  35827,
#  35888,
#  36022,
#  36267,
#  36512,
#  36607,
#  36827,
#  37047,
#  37314,
#  37601,
#  37703,
#  37885,
#  38027,
#  38136,
#  38312,
#  38422,
#  38514,
#  38598,
#  38688,
#  38769,
#  38849,
#  38936,
#  39017,
#  39080,
#  39167,
#  39260,
#  39329,
#  39795,
#  40261,
#  40711,
#  40898,
#  41085,
#  41317,
#  41386,
#  41503,
#  41631,
#  41805,
#  42059,
#  42305,
#  42607,
#  42812,
#  42981,
#  43229,
#  43487,
#  43685,
#  43883,
#  44002,
#  44200,
#  44487,
#  44792,
#  44972,
#  45167,
#  45295,
#  45414,
#  45511,
#  45692,
#  45873,
#  46422,
#  46580,
#  46707,
#  46846,
#  47012,
#  47183,
#  47312,
#  47550,
#  47710,
#  47771,
#  47971,
#  48174,
#  48458,
#  48639,
#  48764,
#  48884,
#  49042,
#  49112,
#  49199,
#  49280,
#  49362,
#  49462,
#  49562,
#  49719,
#  49876,
#  50027,
#  50195,
#  50295,
#  50531,
#  50728,
#  50886,
#  51066,
#  51319,
#  51567,
#  51643,
#  51716,
#  51789,
#  51867,
#  52025,
#  52183,
#  52345,
#  52503,
#  52665,
#  52822,
#  52943,
#  53181,
#  53261,
#  53403,
#  53520,
#  53638,
#  53769,
#  53848,
#  53999,
#  54080,
#  54281,
#  54483,
#  54637,
#  54798,
#  54962,
#  55118,
#  55279,
#  55352,
#  55421,
#  55552,
#  55690,
#  55763,
#  55834,
#  55919,
#  56004,
#  56089,
#  56208,
#  56363,
#  56525,
#  56634,
#  56720,
#  56854,
#  56921,
#  57176,
#  57227,
#  57301,
#  57381,
#  57465,
#  57578,
#  57674,
#  57878,
#  58084,
#  58290,
#  58498,
#  58625,
#  58728,
#  58800,
#  58991,
#  59200,
#  59409,
#  59485,
#  59563,
#  59661,
#  59755,
#  59944,
#  60096,
#  60407,
#  60739,
#  60874,
#  61009,
#  61080,
#  61268,
#  61444,
#  61601,
#  62092,
#  62255,
#  62446,
#  62683,
#  62880,
#  63109,
#  63228,
#  63338,
#  63442,
#  63597,
#  63782,
#  63895,
#  64011,
#  64193,
#  64429,
#  64593,
#  64993,
#  65238,
#  65490,
#  65639,
#  65733,
#  65807,
#  65987,
#  66157,
#  66279,
#  66352,
#  66499,
#  66711,
#  66841,
#  67013,
#  67108,
#  67255,
#  67470,
#  67655,
#  67762,
#  68020,
#  68144,
#  68286,
#  68497,
#  68708,
#  69002,
#  69293,
#  69395,
#  69525,
#  69672,
#  69919,
#  69984,
#  70049,
#  70124,
#  70427,
#  70632,
#  70750,
#  70989,
#  71261,
#  71372,
#  71447,
#  71680,
#  72153,
#  72481,
#  72769,
#  72975,
#  73182,
#  73403,
#  73687,
#  73876,
#  74056,
#  74384,
#  74729,
#  75080,
#  75287,
#  75494,
#  75701,
#  76033,
#  76308,
#  76826,
#  77103,
#  77347,
#  77416,
#  77550,
#  77624,
#  77786,
#  77960,
#  78093,
#  78225,
#  78406,
#  78679,
#  79267,
#  79859,
#  80590,
#  80769,
#  81064,
#  81218,
#  81417,
#  81591,
#  81804,
#  82070,
#  82288,
#  82575,
#  82872,
#  83170,
#  83407,
#  83640,
#  83808,
#  83991,
#  84206,
#  84418,
#  84587,
#  84842,
#  85049,
#  85463,
#  85888,
#  86116,
#  86349,
#  86678,
#  86935,
#  87056,
#  87341,
#  87558,
#  87771,
#  87936,
#  88165,
#  88401,
#  88589,
#  88822,
#  89015,
#  89247,
#  89438,
#  89688,
#  89878,
#  90080,
#  90304,
#  90597,
#  90862,
#  91141,
#  91391,
#  91605,
#  91772,
#  91839,
#  92962,
#  93067,
#  93266,
#  93443,
#  93663,
#  93797,
#  93994,
#  94381,
#  94592,
#  94901,
#  95158,
#  95442,
#  95682,
#  95931,
#  96163,
#  96421,
#  96608,
#  96696,
#  96852,
#  97036,
#  97194,
#  97372,
#  97517,
#  97619,
#  97785,
#  98058,
#  98384,
#  98596,
#  98834,
#  99069,
#  99378,
#  99561,
#  99750,
#  99937,
#  100116,
#  100317,
#  100510,
#  100711,
#  100973,
#  101215,
#  101446,
#  101682,
#  101886,
#  102188,
#  102502,
#  102683,
#  102900,
#  103109,
#  103252,
#  103464,
#  103726,
#  103857,
#  104063,
#  104323,
#  104631,
#  104805,
#  105114,
#  105377,
#  105553,
#  105775,
#  105900,
#  106055,
#  106211,
#  106970,
#  107503,
#  107778,
#  108141,
#  108375,
#  108605,
#  108881,
#  109105,
#  109212,
#  109514,
#  109678,
#  109915,
#  110051,
#  110271,
#  110572,
#  110741,
#  111000,
#  111292,
#  111546,
#  111741,
#  111923,
#  112212,
#  112368,
#  112486,
#  112763,
#  112884,
#  113012,
#  113372,
#  113528,
#  113725,
#  113971,
#  114206,
#  114448,
#  114593,
#  114767,
#  115097,
#  115206,
#  115316,
#  115501,
#  116122,
#  116327,
#  116566,
#  116839,
#  117068,
#  117329,
#  117518,
#  117710,
#  117986,
#  118108,
#  118247,
#  118494,
#  118820,
#  118936,
#  119143,
#  119280,
#  119523,
#  119782,
#  120006,
#  120310,
#  120594,
#  120887,
#  121160,
#  121423,
#  121644,
#  121881,
#  122129,
#  122338,
#  122549,
#  122765,
#  122851,
#  123113,
#  123240,
#  123412,
#  123518,
#  123754,
#  124053,
#  124153,
#  124275,
#  124458,
#  124652,
#  124927,
#  125199,
#  125407,
#  125617,
#  125779,
#  125942,
#  126188,
#  126332,
#  126517,
#  126742,
#  126902,
#  127044,
#  127263,
#  127489,
#  127603,
#  127768,
#  127924,
#  128126,
#  128331,
#  128546,
#  128668,
#  128809,
#  129001,
#  129227,
#  129596,
#  129905,
#  130169,
#  130385,
#  130776,
#  130949,
#  131138,
#  131220,
#  131414,
#  131530,
#  131690,
#  131797,
#  132051,
#  132258,
#  132596,
#  132890,
#  133005,
#  133204,
#  133355,
#  133530,
#  133631,
#  133811,
#  133894,
#  134018,
#  134134,
#  134346,
#  134453,
#  134592,
#  134795,
#  135066,
#  135219,
#  135395,
#  135806,
#  135973,
#  136077,
#  136261,
#  136416,
#  136598,
#  136812,
#  137084,
#  137295,
#  137605,
#  137677,
#  137898,
#  138701,
#  138869,
#  138995,
#  139334,
#  139525,
#  139858,
#  139954,
#  140281,
#  140584,
#  140714,
#  140892,
#  141190,
#  141348,
#  141456,
#  141666,
#  141879,
#  142008,
#  142111,
#  142500,
#  142739,
#  142870,
#  142998,
#  143169,
#  143331,
#  143421,
#  143630,
#  143742,
#  143947,
#  144246,
#  145041,
#  145150,
#  145331,
#  145619,
#  145796,
#  145931,
#  146192,
#  146370,
#  146559,
#  146808,
#  146925,
#  147137,
#  147354,
#  147469,
#  147715,
#  147845,
#  148083,
#  148303,
#  148483,
#  148597,
#  148830,
#  149068,
#  149262,
#  149458,
#  149676,
#  149880,
#  150003,
#  150105,
#  150327,
#  150570,
#  150925,
#  151075,
#  151192,
#  151298,
#  151452,
#  151743,
#  152037,
#  152291,
#  152511,
#  152795,
#  153032,
#  153227,
#  153464,
#  153651,
#  153792,
#  153986,
#  154192,
#  154319,
#  154461,
#  154617,
#  154793,
#  154941,
#  155153,
#  155297,
#  155550,
#  155666,
#  155849,
#  155957,
#  156106,
#  156264,
#  156406,
#  156575,
#  156836,
#  157028,
#  157137,
#  157328,
#  157659,
#  157870,
#  158045,
#  158154,
#  158395,
#  158540,
#  158747,
#  158856,
#  158969,
#  159271,
#  159559,
#  159845,
#  160125,
#  160403,
#  160563,
#  160716,
#  160930,
#  161248,
#  161403,
#  161661,
#  161877,
#  162181,
#  162329,
#  162607,
#  162745,
#  162947,
#  163079,
#  163235,
#  163372,
#  163730,
#  163970,
#  164208,
#  164430,
#  164691,
#  164885,
#  165164,
#  165303,
#  165433,
#  165635,
#  165867,
#  166117,
#  166282,
#  166406,
#  166544,
#  166683,
#  166852,
#  167141,
#  167280,
#  167657,
#  168064,
#  168392,
#  168505,
#  168741,
#  169191,
#  169309,
#  169614,
#  169877,
#  170160,
#  170429,
#  170737,
#  170968,
#  171072,
#  171294,
#  171443,
#  171550,
#  171647,
#  171789,
#  171992,
#  172130,
#  172373,
#  172616,
#  172853,
#  173058,
#  173264,
#  173421,
#  173580,
#  173927,
#  174086,
#  174270,
#  174489,
#  174598,
#  174739,
#  174910,
#  175294,
#  175536,
#  175694,
#  175966,
#  176316,
#  176483,
#  176977,
#  177128,
#  177365,
#  177576,
#  177805,
#  177931,
#  178346,
#  178502,
#  178738,
#  178880,
#  179146,
#  179444,
#  179719,
#  179990,
#  180068,
#  180207,
#  180457,
#  180647,
#  180780,
#  181098,
#  181364,
#  181529,
#  181788,
#  182127,
#  182462,
#  182745,
#  183100,
#  183478,
#  183709,
#  183958,
#  184167,
#  184496,
#  184831,
#  184935,
#  185061,
#  185566,
#  186304,
#  186555,
#  186799,
#  186973,
#  187388,
#  187565,
#  187781,
#  187932,
#  188112,
#  188274,
#  188502,
#  188626,
#  188843,
#  188984,
#  189259,
#  189601,
#  189872,
#  189975,
#  190266,
#  190408,
#  190728,
#  190984,
#  191234,
#  191644,
#  192068,
#  192234,
#  192531,
#  192754,
#  193040,
#  193356,
#  193596,
#  193728,
#  194057,
#  194263,
#  194617,
#  194746,
#  194863,
#  194973,
#  195179,
#  195311,
#  195445,
#  195602,
#  195750,
#  195953,
#  196173,
#  196456,
#  196681,
#  196818,
#  197023,
#  197277,
#  197380,
#  197507,
#  197634,
#  197744,
#  197832,
#  198164,
#  198497,
#  198737,
#  198937,
#  199154,
#  199616,
#  199887,
#  200510,
#  200684,
#  201041,
#  201257,
#  201476,
#  201716,
#  201838,
#  202189,
#  202265,
#  202441,
#  202569,
#  202770,
#  203084,
#  203325,
#  203572,
#  203685,
#  203834,
#  203982,
#  204131,
#  204420,
#  204574,
#  204883,
#  205051,
#  205326,
#  205456,
#  205595,
#  205700,
#  205941,
#  206246,
#  206586,
#  206674,
#  206991,
#  207314,
#  207603,
#  207878,
#  208187,
#  208317,
#  208527,
#  208795,
#  209071,
#  209281,
#  209408,
#  209658,
#  209970,
#  210230,
#  210380,
#  210658,
#  210932,
#  211111,
#  211331,
#  211426,
#  211784,
#  212146,
#  212503,
#  212785,
#  213067,
#  213377,
#  213686,
#  ...]

# %%
# from itertools recipes
def pairwise(iterable, fillvalue=None):
    """
       This function iterates through the list of tokens and 
       creates sub list to include tokens related to one job ad only
    """
    a, b = iter(iterable), iter(iterable)
    next(b, None)
    return itertools.zip_longest(a, b, fillvalue=fillvalue)

# pairwise based on indexes in the last block and store in the 'tokenised' as a list
tokenised = [tokenised[i:j] for i,j in pairwise(indexes)]

# %% [markdown]
# - Exclude words less than 4 char:
#
# - I have kept all the tokens which are more than 3 characters and renamed the rest to 'to_removed
#
# - "to_remove" is added to "stopwords" list further down

# %%
tokenised = [[word if len(word) > 3 else "to_remove" for word in job] for job in tokenised]

# %% [markdown]
# ### Removing stopwords

# %%
# adding'to_removed' string to the list of stopwords
stopwords = []
with open('stopwords_en.txt',"a") as f:
    f.write("\nto_remove") #\n to shift to next line

# %%
with open('stopwords_en.txt') as f:
    stopwords = f.read().splitlines() #reading stopwords line and create stopwords as a list

# %%
# convert stopwords into set
# Python set is better choice than list. 
# Set runs much faster than lists in terms of searching a large number of hashable items

stopwordsset = set(stopwords)

# %%
def purifier(tokenList,remove_token):
    """
        This function takes two input (list of current tokens and list of tokens to be removed)
        The function converts the list into set to improve the performance
        and return a list of sets each of which include purified tokens
        and remove_token lists are removed
    """
    return [set(word for word in job if word not in remove_token) for job in tokenList]

# %%
# running 'purifier' function
tokenised = purifier(tokenised,stopwordsset)

# %% [markdown]
# You need to remove the words that appear only once in one job advertisement description, save them ( No duplication) as a txt file (refer to the required output). You will need to exclude those words in the generated vocabulary.

# %%
# Using chain() function to join all the words in all the job ads together by making a list
stop_wrds_removed_words = list(chain.from_iterable([word for word in job] for job in tokenised))
# convert the list of words into set to remove duplicates and create the set of vocabulary
stop_wrds_removed_vocab = set(stop_wrds_removed_words)
# passing the words in FreqDisrt() function to cound the number of token
# this function counts the number of times a word occurs in the whole corpus regardless which ad it is in.
fd = FreqDist(stop_wrds_removed_words)

# %%
# finding the Less Frequent Tokens.

# create a list of token which have occured more than once
# convert the list into set for performance improvement
once_only = set([k for k, v in fd.items() if v == 1])
# sort the set into alphabetical order
once_only = sorted(once_only)

set(once_only)
# Out:
# {'deputymanager',
#  'tolerences',
#  'tilt',
#  'jointing',
#  'unfortunatley',
#  'kategimrfood',
#  'uccx',
#  'joeexactsourcing',
#  'revising',
#  'facilitiesmanagementconsultant',
#  'leagrave',
#  "user's",
#  'hucknall',
#  'inco',
#  'nbspremuneration',
#  'floodriskconsultantmodeller',
#  'parmesan',
#  "gsce's",
#  'prepping',
#  'samantha',
#  'nonlanguage',
#  'oxfordshirerecruiting',
#  'cominterquest',
#  'rolesupports',
#  'watlington',
#  'obsessive',
#  'sprayer',
#  'mechanicalengineerleicesterleicestershire',
#  'willington',
#  'vliw',
#  'knowledgehave',
#  'maintenanceteamleader',
#  'powercli',
#  'abbishawbupa',
#  'phusion',
#  'suiteadvanced',
#  'seniorrubydeveloperteamleader',
#  'identyfy',
#  'designssafe',
#  'sqlable',
#  'deduction',
#  'nspcc',
#  'enterpriseminer',
#  'nodes',
#  'servicenow',
#  'differs',
#  'patternsexperience',
#  'techy',
#  'gilt',
#  'sharepointsolutionanalystdeveloper',
#  'instructionsstrong',
#  'clauses',
#  'glms',
#  'sisgter',
#  'comradeship',
#  'userinterface',
#  'arenas',
#  'decorative',
#  'furthered',
#  'rafiki',
#  'whats',
#  'carand',
#  'loaded',
#  'ambu',
#  'preexisting',
#  'businees',
#  'developersmanagement',
#  'desigo',
#  'administrate',
#  'vague',
#  'shits',
#  'accommodating',
#  'optimisationremarketingmaintaining',
#  'demandware',
#  'neverending',
#  'eusoc',
#  'multiuse',
#  'fireworksasp',
#  'pretransition',
#  'javascriptcrossbrowser',
#  'troubleshoottake',
#  'muratsubaki',
#  'immerse',
#  "ecu's",
#  'landline',
#  'newer',
#  'mobberley',
#  'postoffer',
#  'plane',
#  'complain',
#  'rscs',
#  'glmms',
#  'mbse',
#  'vicky',
#  'customerrelating',
#  'supervises',
#  'developmentexperience',
#  'homeland',
#  'deposit',
#  'analyzes',
#  'nigeria',
#  'aces',
#  'stans',
#  'resultsfocused',
#  'infestations',
#  'teamfocussed',
#  'ceremonies',
#  'hatfieldacromas',
#  'cics',
#  "bgb's",
#  'gatheringthis',
#  'isis',
#  'incinerator',
#  'hoisting',
#  'gammon',
#  'rosettehotel',
#  'planningaccount',
#  'systemskeep',
#  'impetus',
#  'customersattend',
#  'reportscollaboratively',
#  'joinging',
#  'ratatouille',
#  'stefanhanoversearch',
#  'dsear',
#  'formalizing',
#  'recruitmentcontact',
#  'pressbraking',
#  'nonpower',
#  'agenct',
#  'jdeveloper',
#  'skillsthis',
#  'heuristics',
#  'choise',
#  'nbsprenewables',
#  'synchronizer',
#  'lynton',
#  'increments',
#  'stocksfield',
#  'manipulated',
#  'climates',
#  'sanctuary',
#  'iterate',
#  'codesign',
#  'dataswitch',
#  'vera',
#  'gigevision',
#  'setssand',
#  'webservice',
#  'democratic',
#  'dictate',
#  'crossclient',
#  'comiis',
#  "international's",
#  'darwen',
#  'subs',
#  'expeditormaterialplanner',
#  'omagh',
#  'simpana',
#  "king's",
#  'rightly',
#  'objectrelational',
#  'foams',
#  'newopeningexcitingbrandstalbans',
#  'betterment',
#  'meprojectmanager',
#  'accpac',
#  'clientsskills',
#  'instancesability',
#  'showpiece',
#  'industryc',
#  'korn',
#  'ofcom',
#  'donkorpulsejobs',
#  'agreementsmonitor',
#  'sigmoidoscopy',
#  'recoding',
#  'accompaniments',
#  'folowing',
#  'bullqualified',
#  'viruses',
#  'dyspraxia',
#  'heartland',
#  'procuring',
#  'reportsinvolvement',
#  'tipsipswichoutskirts',
#  'doxford',
#  'servicea',
#  'breakfastchefrequired',
#  'levelthe',
#  'nonaudit',
#  'useable',
#  'burwell',
#  'seniorelectricaldesignengineerassociatedesignate',
#  'entitles',
#  'advancedmanufacturingengineer',
#  'standardsfriendly',
#  'oensuring',
#  'hotkey',
#  'casuals',
#  'fusions',
#  'jockey',
#  'initialise',
#  'marissa',
#  'packagemy',
#  'auction',
#  "appointment's",
#  'personas',
#  'commischefrespectedcountryinntipshelptorelocate',
#  'marrieaforappointments',
#  'gasifiers',
#  'newham',
#  'awfs',
#  'seniorchefdepartielancashire',
#  'sideshows',
#  'thorpe',
#  'generalmanagerbrilliantcompanynorthlondon',
#  'tagliatelli',
#  'shiftengineerperm',
#  'recreational',
#  'opportuinity',
#  'cfirst',
#  'dylan',
#  'knee',
#  'sprits',
#  'accompaniment',
#  'cpcsroughterraintelescopicforkliftdriver',
#  'coupondropdown',
#  'misconfiguration',
#  'handsone',
#  'opportunitynet',
#  'ourlondonteam',
#  'simplicity',
#  'katybeerecruitment',
#  'perseverance',
#  'raes',
#  'juniorsouschefawardwinninghotelgoodcompanybenefits',
#  'prone',
#  'chefdepartiemodernhighvolumehotelfreshfoodgoodtips',
#  'jasmine',
#  'healthchecks',
#  'portugal',
#  'prerenewal',
#  'debate',
#  'substantively',
#  'worksave',
#  'uksalary',
#  'endpoint',
#  'misdescriptions',
#  'cranleight',
#  'skoda',
#  'hanningfield',
#  'taqa',
#  'cutoffs',
#  'bikes',
#  'rows',
#  'selfdisciplined',
#  'cort',
#  'assistantmanagerbrilliantbrandedrestaurantnorthlondon',
#  'tiles',
#  'chefdepartiehighvolumebanquetingdepartmentallfreshfood',
#  'entitling',
#  'cutlery',
#  'thorughout',
#  'termtime',
#  'flats',
#  'wimes',
#  'proposalodelivers',
#  'remembering',
#  'electroplating',
#  'illhealth',
#  'restatement',
#  'analog',
#  'acoustical',
#  'satellites',
#  'biggleswade',
#  'clock',
#  'swabs',
#  'endorsed',
#  'representives',
#  'teama',
#  'sink',
#  'carrie',
#  'bundy',
#  'connectdirect',
#  'impede',
#  'wellversed',
#  'rporate',
#  'exhibitor',
#  'expertlevel',
#  'opencl',
#  'timeout',
#  'experienceproven',
#  'commischefmichelinstarsouthwales',
#  'hanging',
#  'waterhygienefitterplumberkent',
#  'tagman',
#  'attainments',
#  'href',
#  'liquefaction',
#  'firmstability',
#  'supplieraccountmanager',
#  'ppto',
#  'representations',
#  'proceedures',
#  'obstacle',
#  'fitgap',
#  'greig',
#  'skillsfamiliarity',
#  'everify',
#  'revises',
#  'flooding',
#  'extruding',
#  'cexcel',
#  'outlooks',
#  'slot',
#  'harnessing',
#  'skinny',
#  'phyton',
#  'unicode',
#  'regimented',
#  'salessupportmanagerpresalesprojectmanagement',
#  'teaacher',
#  'workbooks',
#  "fund's",
#  'privde',
#  'humus',
#  'nuglach',
#  'resultbased',
#  'rolethe',
#  'perspectives',
#  'developmentgitdon',
#  'confectionary',
#  'lianne',
#  'altricnham',
#  'aper',
#  'companyspecific',
#  'levelan',
#  'weakness',
#  'incisive',
#  'qualitycontrolteamleader',
#  'homewares',
#  'mate',
#  'appending',
#  'drill',
#  'geounit',
#  'unguided',
#  'bromford',
#  'owens',
#  'scroll',
#  'instructors',
#  'couplings',
#  'spools',
#  'jfrostprotocoleducation',
#  'discs',
#  'physicist',
#  'ddms',
#  'necessarybusiness',
#  'qswolder',
#  'overarching',
#  'wastebaskets',
#  'clientto',
#  'mealtimes',
#  'rotations',
#  'hrefmailto',
#  'tribal',
#  'failover',
#  'cola',
#  'projectsengineer',
#  'joinerfactoryworker',
#  'item',
#  'conductive',
#  'hifi',
#  'techniqueshave',
#  "mind's",
#  'fuels',
#  'appertaining',
#  'combustors',
#  'icob',
#  'expererience',
#  'biomechanics',
#  'hoiuejuselbyjenningsaptrackcouk',
#  'intrastats',
#  'transfusion',
#  'edgerton',
#  'verma',
#  'echo',
#  'tbruntcitizenrecruitment',
#  'bernard',
#  'wincc',
#  'vonsternbergworksolutions',
#  'memberskey',
#  'bashing',
#  'complease',
#  'environmentsowns',
#  'nowadays',
#  'throught',
#  'gclp',
#  'cameron',
#  'closest',
#  'gret',
#  'recirculating',
#  'prevented',
#  'rosetteawarded',
#  'inprocess',
#  'mysqlcakephp',
#  'telecomsresponding',
#  'yorkshirehumberoptimastraining',
#  'severity',
#  'wake',
#  'proviving',
#  'trafficker',
#  "strategy's",
#  "agency's",
#  'recruting',
#  'experiencejob',
#  'morphx',
#  'thesouthcoast',
#  'nonspecialist',
#  'applianceengineerwhitegoods',
#  'neurotic',
#  'inlduing',
#  'mpvs',
#  'acams',
#  'counterbalancefltdriver',
#  'dome',
#  'registry',
#  'deleting',
#  'performant',
#  "practitioner's",
#  'productionengineeringmanager',
#  'chefdepartiecountryhousehoteldevelopmentopportunities',
#  'analystyorkshire',
#  'rosettesouschefnorthampton',
#  'concentrated',
#  'daysplease',
#  'buys',
#  'ratahours',
#  'oleum',
#  'ohio',
#  'blup',
#  'hurry',
#  'baby',
#  'immunology',
#  'striking',
#  'barnetby',
#  'takeover',
#  'frayed',
#  'studious',
#  'combe',
#  'vitalisation',
#  'cowley',
#  'classed',
#  'followingup',
#  'commischefluxuryfourstarhotelstraightshiftsdiscounts',
#  'anthony',
#  'nontraded',
#  'woodland',
#  'newcomer',
#  'taxed',
#  'empathise',
#  'capsule',
#  'dsdm',
#  'haters',
#  'brochure',
#  "ecg's",
#  'sockets',
#  'adams',
#  'generalmanagerrestaurantopeninggrowinggroupmiltonkeynes',
#  'czech',
#  'microns',
#  'nowhays',
#  'tesol',
#  'airwatch',
#  'assistantaylesbury',
#  'shipmanagerengineer',
#  'recall',
#  'meridian',
#  'aslo',
#  'weatherford',
#  'golden',
#  'newent',
#  'qualificationseffective',
#  'mananging',
#  'mezzo',
#  'converts',
#  'belowimmediate',
#  'sniffing',
#  'joel',
#  'londonduration',
#  'variousbetween',
#  'expereicene',
#  'erector',
#  'cateecah',
#  'barwick',
#  'caleipct',
#  'esol',
#  'sourdoughs',
#  'agentsself',
#  'rnlds',
#  'franchise',
#  'filings',
#  'finchley',
#  'electricaldesignengineerintermediate',
#  'costefficiently',
#  'bordereaux',
#  'intrinsic',
#  'dysreflexia',
#  'yoru',
#  'multiregional',
#  'cyclerisk',
#  'myplymouthbased',
#  'generalmanagerpitcherpianobristol',
#  'sehmihays',
#  'substituted',
#  'channelto',
#  'league',
#  'handing',
#  'postsale',
#  'seniorquantitysurveyorresidentialdevelopment',
#  'harrison',
#  'aerolastic',
#  'hcsws',
#  'oppportunites',
#  'frameworkdemonstrates',
#  'pportunities',
#  'puppies',
#  'frontendwebdeveloperhtmlcssjavascript',
#  'imac',
#  'keswick',
#  'rosettemainkitchentemplivein',
#  'iworsfoldstrgroup',
#  'hfea',
#  'indentured',
#  'exemption',
#  'ascribed',
#  'assimilation',
#  'prolific',
#  'barristers',
#  'prosecution',
#  'seniorelectricaldesignengineer',
#  'drawer',
#  'lisp',
#  'merrygoround',
#  'porth',
#  'harvardbrownltd',
#  'vaadin',
#  'changeman',
#  'bronze',
#  'istanbul',
#  'machinelearning',
#  'excesses',
#  'hsande',
#  'londonan',
#  'magazine',
#  'runners',
#  'messagedriven',
#  'munirm',
#  'joannaaesco',
#  'responsbility',
#  'passions',
#  'organ',
#  'primecare',
#  'shallow',
#  'royce',
#  'basisare',
#  'suppler',
#  'indicator',
#  'moneyhungry',
#  'timefinder',
#  'infocaffev',
#  'swglacah',
#  'etchays',
#  'judge',
#  'batharea',
#  'considred',
#  'django',
#  'pastrycheffor',
#  'tweaks',
#  'sportingbet',
#  'entrant',
#  'hartleykane',
#  'compressed',
#  'unimpaired',
#  'primed',
#  'elsewhereremuneration',
#  'lorraineniyaapeople',
#  'workscopes',
#  'appharbour',
#  'anerley',
#  'misstatements',
#  'flextime',
#  'cpcs',
#  'conformances',
#  'walthamstow',
#  'infocammelllaird',
#  'stacks',
#  'molding',
#  'maricare',
#  'personalise',
#  'reputational',
#  'shopper',
#  'jface',
#  'reassessed',
#  'unvalidated',
#  'managementrequirements',
#  'sssts',
#  'cooperations',
#  'memos',
#  'requiredwe',
#  'civicacrystal',
#  'infoworks',
#  'fantasic',
#  'serviceproviders',
#  'gamma',
#  'calorifiers',
#  'excercises',
#  'environmenttester',
#  'souschefhighregardedfoodledpubliveinavailabletips',
#  'generates',
#  'sonographers',
#  'linea',
#  'characerisation',
#  'fakenham',
#  'signatories',
#  'carbide',
#  'anaesthesia',
#  'butlersykrecruitment',
#  'blow',
#  'bankhall',
#  'ergonomics',
#  'foglight',
#  'stevanage',
#  'burger',
#  'corp',
#  'realities',
#  'aarosettemoderneuropeancuisineliveinoption',
#  'millscoburgbanks',
#  'reflexology',
#  'holme',
#  'panasonic',
#  'basicdemonstrates',
#  'preapprovals',
#  'cheapest',
#  'interrogating',
#  'mckinlay',
#  'chefdepartiemodernbritishdining',
#  'camtasia',
#  'virusscan',
#  'ukstr',
#  'auditable',
#  'athetoid',
#  "ge's",
#  'btech',
#  'lydon',
#  'seanalectorecruitment',
#  'assmembly',
#  'wiht',
#  'hydrocarbon',
#  'latitude',
#  'agentslarge',
#  'doorstep',
#  'retailler',
#  'tomato',
#  'fastener',
#  'diecasting',
#  'paypal',
#  'overtimeasc',
#  'reciprocated',
#  'surreymy',
#  'kmusicentertainmentindustrylondon',
#  'articulately',
#  'leadoperationengineer',
#  'cambridgesalary',
#  'portlets',
#  'whitwell',
#  'clientscheck',
#  'rcslt',
#  'hardening',
#  'butlerroomservicemanager',
#  'spendqualification',
#  'rain',
#  'shaftesbury',
#  'prawn',
#  'kylie',
#  'gprs',
#  'trails',
#  'deliveryperforming',
#  'interviewplease',
#  'qualificationcreation',
#  'traditionally',
#  'fiver',
#  'multispecialist',
#  'anne',
#  'photo',
#  "pub's",
#  'retargeting',
#  'sniffers',
#  'unscheduled',
#  'authorized',
#  'dispenser',
#  'omelettes',
#  'upsserviceengineer',
#  'guilford',
#  'hyton',
#  'responsibilties',
#  'daytest',
#  'refractions',
#  'lsas',
#  'knowleadge',
#  'excite',
#  'napco',
#  'salt',
#  'ollow',
#  'albeit',
#  'autotrack',
#  'familar',
#  'monmore',
#  'andenhancements',
#  'touted',
#  'regulatorycontrolled',
#  'multirise',
#  'indefinitely',
#  'technologiesthe',
#  'filesystem',
#  'telsales',
#  'fishpool',
#  'refresheserp',
#  'clive',
#  'skillsassets',
#  'bother',
#  'differentiating',
#  'fullybookedrecruitment',
#  'franck',
#  'retest',
#  'infrastructural',
#  'coldfieldplease',
#  'sollihull',
#  'nonplanning',
#  'evidenced',
#  'skillsin',
#  'managersrequiredupnationwide',
#  'quinquennial',
#  'squish',
#  "cognizant's",
#  'marcus',
#  'planted',
#  'dmrc',
#  'penetrate',
#  'cpos',
#  'exhausts',
#  'midstream',
#  'subcontracts',
#  'reclaim',
#  'activebatch',
#  'proliferation',
#  'scobol',
#  'australasia',
#  'lomar',
#  'demichefdepartiehighqualitydiningvenuetipslivein',
#  'complianceengineerquality',
#  'concierge',
#  'appropriateto',
#  'recontracting',
#  'dash',
#  'wlan',
#  'endsalary',
#  'laminator',
#  'catchment',
#  'supremely',
#  'nolanitventures',
#  'jobbers',
#  'turnoverextensive',
#  'dcdc',
#  'predetermined',
#  'engagementaccountable',
#  'souschefstablefreshfoodpubfreeliveingoodtips',
#  'leachate',
#  'chefdepartiewellrespectedfoodfocusedhoteltipslivein',
#  'secretariat',
#  'begins',
#  'customerescalated',
#  'breadboard',
#  'ifaprofessional',
#  'colonoscopy',
#  'trainerlocation',
#  'tunbridgewellsbluebirdcare',
#  'environmentsalary',
#  'arqiva',
#  'westend',
#  'vanes',
#  'middleman',
#  'aide',
#  'claimants',
#  'getty',
#  'descriptionabout',
#  'mediumterm',
#  'requesthays',
#  'scriptingsql',
#  'openbet',
#  'collaborates',
#  'aegon',
#  'toes',
#  'ciob',
#  'illford',
#  'impresses',
#  'mobilefiresecurityengineer',
#  'celerra',
#  'strengthened',
#  'psoriasis',
#  'unqual',
#  'capstan',
#  'kfinancialcontroller',
#  'dimentia',
#  'photographic',
#  'bermuda',
#  'purging',
#  'gounds',
#  'adaptors',
#  "opco's",
#  'addins',
#  'dazzle',
#  'endorses',
#  'inexperienced',
#  'simon',
#  'encoder',
#  'esteem',
#  'facade',
#  'implimentaionsif',
#  'utilites',
#  'aerodynamics',
#  'angesprochen',
#  'qualitytrainingmanager',
#  'inca',
#  'interpedently',
#  'riser',
#  'horsted',
#  'traction',
#  'onducting',
#  'precedohealthcare',
#  'benefitswhat',
#  'invitations',
#  'lend',
#  'spar',
#  'toad',
#  'alterafpga',
#  'indentified',
#  'aerodyn',
#  'customerservicesrepresentative',
#  'handpicked',
#  'oddy',
#  'spotlight',
#  'requried',
#  'vegetarian',
#  'infrastructuresextensive',
#  'surestep',
#  'dougherty',
#  'gcrawleystrgroup',
#  'mothertongue',
#  'commischefregionallyfocusedallfreshgastropubshareoftips',
#  'experimental',
#  'worktravailgrantham',
#  'membersimplement',
#  'maintenanceengineerconveyorandfacilitiessupport',
#  'bamber',
#  'dotnet',
#  'selfesteem',
#  'targetfocused',
#  'productdevelopmentmanager',
#  'screaming',
#  'payscales',
#  "thamesvalley's",
#  'broadcasts',
#  'manchestersenior',
#  'incidences',
#  'improvementclient',
#  'sores',
#  'flatted',
#  'barbican',
#  'plymstock',
#  'shefffield',
#  'barrier',
#  'featherstone',
#  'teamproactive',
#  'rigsbill',
#  'londonoffice',
#  'reprt',
#  'experineced',
#  'manufacturingproductionengineerengineassembly',
#  'manchesterour',
#  'moyes',
#  'formfiller',
#  'partnersounderstands',
#  'hast',
#  'distinguish',
#  'seniorpublichealthdesignengineer',
#  'aspthe',
#  'spoke',
#  'routed',
#  'nivrobviously',
#  'bullexperience',
#  'nutshell',
#  'assistanthotelmanager',
#  'coaches',
#  'windowstrong',
#  'cryptographic',
#  'alleged',
#  'masks',
#  'londonnearest',
#  'highlycompetitive',
#  'sunwed',
#  'hierarchical',
#  'exadata',
#  'fellows',
#  'oproactively',
#  'pcidss',
#  'detiox',
#  'royston',
#  'calibrate',
#  'collectives',
#  'lemon',
#  'withstand',
#  'balfor',
#  'nextlevel',
#  'strand',
#  'pciexpress',
#  'secondline',
#  'dinnington',
#  'seniortechnicalmanagerstructuralmonitoring',
#  'edinburgha',
#  'floodlighting',
#  'agencyadecco',
#  'armour',
#  'forensics',
#  'shrink',
#  'concasses',
#  'sifting',
#  'salient',
#  'officially',
#  'bagging',
#  'gaskets',
#  'westfield',
#  'qualifiedhelping',
#  'hotelberkshire',
#  'bypasses',
#  'bathe',
#  'ripon',
#  'commischefgreattrainingprospectshighstandardvenue',
#  'telecomengineer',
#  'unification',
#  'buoyant',
#  'frameworkknowledge',
#  'clas',
#  'intellectually',
#  'piecewise',
#  'architectlevel',
#  'ccompliant',
#  'suspicions',
#  'clamps',
#  'expereinced',
#  'tutoring',
#  'solderer',
#  'acumenbeing',
#  "microp's",
#  'polymorphism',
#  'spreadbetting',
#  'practicality',
#  'harris',
#  'oxidisers',
#  'businessesresponsible',
#  'sedgebrook',
#  'abbeymead',
#  'cary',
#  'essentialrequirement',
#  'compliantly',
#  'doubles',
#  'internallyraised',
#  'expeirence',
#  'onus',
#  'regentrec',
#  'absenceto',
#  'customized',
#  'seniorpastrychefdepartiemultioutlethotelhighstandards',
#  'telecare',
#  'lining',
#  'mappersdependency',
#  'cornerstone',
#  'chefdepartiehighqualitymultioutlethotelvolumecooking',
#  'lithuania',
#  'multinationalslough',
#  'wests',
#  'buckets',
#  'seancrconline',
#  'rrequired',
#  'membrane',
#  'piggy',
#  'requisitioned',
#  'layoutembedded',
#  'communicationstrong',
#  'consultatively',
#  ...}

# %% [markdown]
# ### lowFreq.txt
# - Saving the sorted list of the words that appear only once in one job advertisement description to a file

# %%
out_file = open("lowFreq.txt", 'w')
for d in once_only:
    out_file.write(''.join(d) + '\n')
out_file.close()

# %%
# At this stage, I repead the same steps above
# However, this time the intention is to find the highFreq words
# start from removing lowFreq tokens from the list of tokens

tokenised = purifier(tokenised,once_only)

# %% [markdown]
# - Now, I'm going to create a new list of words after once_only words are removed

# %%
LowFreqRemoved_Words = list(chain.from_iterable([word for word in job] for job in tokenised))
LowFreqRemoved_vocab = set(LowFreqRemoved_Words)
LowFreqRemoved_fd = FreqDist(LowFreqRemoved_Words)

# %%
highFreq = set([k for k, v in LowFreqRemoved_fd.items() if v > 100])

# %% [markdown]
# ### highFreq.txt
# - Saving the sorted list of high frequent words that appear in more than 100 job advertisement description to a file

# %%
out_file = open("highFreq.txt", 'w')
for d in highFreq:
    out_file.write(''.join(d) + '\n')
out_file.close()

# %%
set(highFreq)
# Out:
# {'ability',
#  'accept',
#  'access',
#  'accommodation',
#  'accordance',
#  'account',
#  'accounting',
#  'accounts',
#  'accurate',
#  'achieve',
#  'achieving',
#  'acting',
#  'active',
#  'actively',
#  'activities',
#  'activity',
#  'acts',
#  'addition',
#  'additional',
#  'address',
#  'administration',
#  'adults',
#  'advanced',
#  'advantage',
#  'advantageous',
#  'advertised',
#  'advice',
#  'agencies',
#  'agency',
#  'agile',
#  'agreed',
#  'allowance',
#  'alongside',
#  'alternatively',
#  'ambitious',
#  'analysis',
#  'analyst',
#  'analytical',
#  'annual',
#  'annum',
#  'applicant',
#  'applicants',
#  'application',
#  'applications',
#  'apply',
#  'applying',
#  'appointments',
#  'approach',
#  'architecture',
#  'area',
#  'areas',
#  'arisen',
#  'asap',
#  'aspects',
#  'assess',
#  'assessment',
#  'assessments',
#  'assignments',
#  'assist',
#  'assistance',
#  'assistant',
#  'assistants',
#  'assisting',
#  'associates',
#  'assurance',
#  'asylum',
#  'attend',
#  'attention',
#  'attitude',
#  'attributes',
#  'audits',
#  'authority',
#  'automotive',
#  'availability',
#  'award',
#  'aware',
#  'awareness',
#  'back',
#  'background',
#  'bank',
#  'base',
#  'based',
#  'basic',
#  'basis',
#  'behalf',
#  'behaviour',
#  'beneficial',
#  'benefit',
#  'benefits',
#  'birmingham',
#  'bonus',
#  'brand',
#  'brown',
#  'budget',
#  'build',
#  'building',
#  'built',
#  'business',
#  'busy',
#  'button',
#  'call',
#  'calls',
#  'candidate',
#  'candidates',
#  'capable',
#  'capacity',
#  'care',
#  'career',
#  'carers',
#  'caring',
#  'carry',
#  'case',
#  'cases',
#  'caterer',
#  'catering',
#  'central',
#  'centre',
#  'challenge',
#  'challenging',
#  'chance',
#  'change',
#  'check',
#  'checks',
#  'chef',
#  'chefs',
#  'children',
#  'choice',
#  'circa',
#  'city',
#  'class',
#  'clean',
#  'clear',
#  'click',
#  'clicking',
#  'client',
#  'clients',
#  'clinical',
#  'close',
#  'closely',
#  'code',
#  'colleagues',
#  'comfortable',
#  'commercial',
#  'commission',
#  'commitment',
#  'committed',
#  'communicate',
#  'communication',
#  'communications',
#  'communicator',
#  'community',
#  'commutable',
#  'companies',
#  'company',
#  'competent',
#  'competitive',
#  'complete',
#  'completed',
#  'completion',
#  'complex',
#  'compliance',
#  'components',
#  'comprehensive',
#  'computer',
#  'conditions',
#  'conduct',
#  'confidence',
#  'confident',
#  'configuration',
#  'considered',
#  'consultancy',
#  'consultant',
#  'consultants',
#  'consulting',
#  'contact',
#  'contacted',
#  'continue',
#  'continued',
#  'continuous',
#  'contract',
#  'contracts',
#  'contribute',
#  'control',
#  'controls',
#  'cooking',
#  'copy',
#  'core',
#  'corporate',
#  'cost',
#  'country',
#  'cover',
#  'covering',
#  'create',
#  'creating',
#  'creative',
#  'criteria',
#  'critical',
#  'current',
#  'customer',
#  'customers',
#  'cycle',
#  'daily',
#  'data',
#  'database',
#  'date',
#  'days',
#  'deadlines',
#  'deal',
#  'dealing',
#  'decision',
#  'dedicated',
#  'degree',
#  'deliver',
#  'delivered',
#  'delivering',
#  'delivery',
#  'dementia',
#  'demonstrable',
#  'demonstrate',
#  'department',
#  'departments',
#  'dependent',
#  'depending',
#  'deputy',
#  'description',
#  'design',
#  'designing',
#  'designs',
#  'desirable',
#  'desire',
#  'detail',
#  'detailed',
#  'details',
#  'develop',
#  'developed',
#  'developer',
#  'developers',
#  'developing',
#  'development',
#  'difference',
#  'digital',
#  'dining',
#  'direct',
#  'direction',
#  'directly',
#  'director',
#  'disabilities',
#  'disability',
#  'discipline',
#  'disciplines',
#  'disclosure',
#  'discuss',
#  'diverse',
#  'division',
#  'document',
#  'documentation',
#  'documented',
#  'documents',
#  'domestic',
#  'drawings',
#  'drive',
#  'driven',
#  'driver',
#  'driving',
#  'duties',
#  'duty',
#  'dynamic',
#  'earn',
#  'east',
#  'easy',
#  'eclypse',
#  'eden',
#  'edge',
#  'educated',
#  'education',
#  'effective',
#  'effectively',
#  'efficient',
#  'elderly',
#  'electrical',
#  'eligibility',
#  'eligible',
#  'email',
#  'employee',
#  'employees',
#  'employer',
#  'employment',
#  'enable',
#  'energy',
#  'engineer',
#  'engineering',
#  'engineers',
#  'england',
#  'english',
#  'enhance',
#  'enhanced',
#  'enjoy',
#  'ensure',
#  'ensuring',
#  'enterprise',
#  'enthusiastic',
#  'environment',
#  'environments',
#  'equal',
#  'equality',
#  'equipment',
#  'equivalent',
#  'essential',
#  'establish',
#  'established',
#  'europe',
#  'evenings',
#  'events',
#  'evidence',
#  'excel',
#  'excellence',
#  'excellent',
#  'exceptional',
#  'exciting',
#  'executive',
#  'existing',
#  'expanding',
#  'expansion',
#  'expect',
#  'expectations',
#  'expected',
#  'experience',
#  'experienced',
#  'expert',
#  'expertise',
#  'exposure',
#  'extensive',
#  'external',
#  'facilities',
#  'facing',
#  'families',
#  'family',
#  'fantastic',
#  'fast',
#  'feedback',
#  'feel',
#  'field',
#  'finance',
#  'financial',
#  'find',
#  'finding',
#  'firm',
#  'flexibility',
#  'flexible',
#  'focus',
#  'focused',
#  'follow',
#  'food',
#  'form',
#  'forward',
#  'found',
#  'frail',
#  'framework',
#  'free',
#  'fresh',
#  'friday',
#  'friendly',
#  'full',
#  'fully',
#  'function',
#  'functional',
#  'functions',
#  'future',
#  'gain',
#  'gained',
#  'general',
#  'generation',
#  'generous',
#  'genuine',
#  'give',
#  'giving',
#  'global',
#  'goals',
#  'good',
#  'graduate',
#  'great',
#  'group',
#  'groups',
#  'grow',
#  'growing',
#  'growth',
#  'guidance',
#  'guidelines',
#  'handling',
#  'hands',
#  'happy',
#  'hard',
#  'hardware',
#  'head',
#  'health',
#  'healthcare',
#  'hear',
#  'held',
#  'helping',
#  'high',
#  'highest',
#  'highly',
#  'hold',
#  'holiday',
#  'holidays',
#  'home',
#  'homes',
#  'honest',
#  'hospital',
#  'hotel',
#  'hour',
#  'hourly',
#  'hours',
#  'house',
#  'html',
#  'ideal',
#  'ideally',
#  'ideas',
#  'identify',
#  'identifying',
#  'immediately',
#  'immigration',
#  'implement',
#  'implementation',
#  'implementing',
#  'important',
#  'improve',
#  'improvement',
#  'improvements',
#  'include',
#  'includes',
#  'including',
#  'increase',
#  'independence',
#  'independent',
#  'independently',
#  'individual',
#  'individuals',
#  'induction',
#  'industries',
#  'industry',
#  'information',
#  'infrastructure',
#  'initial',
#  'initiative',
#  'innovative',
#  'installation',
#  'insurance',
#  'integration',
#  'interest',
#  'interested',
#  'internal',
#  'international',
#  'interpersonal',
#  'interview',
#  'interviews',
#  'investment',
#  'involve',
#  'involved',
#  'issues',
#  'java',
#  'javascript',
#  'jobs',
#  'jobseeking',
#  'join',
#  'joining',
#  'junior',
#  'keen',
#  'keywords',
#  'kitchen',
#  'knowledge',
#  'language',
#  'large',
#  'largest',
#  'latest',
#  'lead',
#  'leader',
#  'leadership',
#  'leading',
#  'leads',
#  'learn',
#  'learning',
#  'legislation',
#  'leisure',
#  'letter',
#  'level',
#  'levels',
#  'liaise',
#  'liaising',
#  'liaison',
#  'licence',
#  'life',
#  'lifecycle',
#  'limited',
#  'line',
#  'linux',
#  'literate',
#  'live',
#  'living',
#  'local',
#  'located',
#  'location',
#  'locations',
#  'london',
#  'long',
#  'love',
#  'made',
#  'main',
#  'maintain',
#  'maintained',
#  'maintaining',
#  'maintenance',
#  'major',
#  'make',
#  'making',
#  'manage',
#  'managed',
#  'management',
#  'manager',
#  'managers',
#  'managing',
#  'manchester',
#  'manner',
#  'manufacturing',
#  'market',
#  'marketing',
#  'markets',
#  'match',
#  'matches',
#  'meals',
#  'mechanical',
#  'media',
#  'medical',
#  'medication',
#  'medium',
#  'meet',
#  'meeting',
#  'meetings',
#  'member',
#  'members',
#  'mental',
#  'microsoft',
#  'midlands',
#  'minimum',
#  'mobile',
#  'modern',
#  'monday',
#  'money',
#  'monitor',
#  'monitoring',
#  'month',
#  'monthly',
#  'months',
#  'motivate',
#  'motivated',
#  'move',
#  'multi',
#  'multidisciplinary',
#  'multiple',
#  'national',
#  'nature',
#  'needed',
#  'negotiable',
#  'network',
#  'networking',
#  'newly',
#  'night',
#  'nights',
#  'north',
#  'note',
#  'notice',
#  'number',
#  'nurse',
#  'nurses',
#  'nursing',
#  'objectives',
#  'offer',
#  'offered',
#  'offering',
#  'offers',
#  'office',
#  'offices',
#  'ongoing',
#  'online',
#  'open',
#  'opening',
#  'operate',
#  'operates',
#  'operating',
#  'operation',
#  'operational',
#  'operations',
#  'opportunities',
#  'opportunity',
#  'order',
#  'organisation',
#  'organisational',
#  'organisations',
#  'organised',
#  'originally',
#  'outstanding',
#  'overtime',
#  'paced',
#  'package',
#  'packages',
#  'paid',
#  'part',
#  'participate',
#  'partie',
#  'partners',
#  'passion',
#  'passionate',
#  'patient',
#  'patients',
#  'pattern',
#  'patterns',
#  'pension',
#  'people',
#  'perform',
#  'performance',
#  'period',
#  'permanent',
#  'person',
#  'personal',
#  'personnel',
#  'phone',
#  'physical',
#  'place',
#  'plan',
#  'planned',
#  'planning',
#  'plans',
#  'plant',
#  'player',
#  'point',
#  'policies',
#  'policy',
#  'portfolio',
#  'position',
#  'positions',
#  'positive',
#  'possess',
#  'post',
#  'posted',
#  'potential',
#  'pound',
#  'practical',
#  'practice',
#  'practices',
#  'preferably',
#  'preferred',
#  'preparation',
#  'prepare',
#  'prepared',
#  'preparing',
#  'present',
#  'presentation',
#  'pressure',
#  'prestigious',
#  'previous',
#  'primary',
#  'principles',
#  'prior',
#  'privacy',
#  'private',
#  'proactive',
#  'problem',
#  'problems',
#  'procedures',
#  'process',
#  'processes',
#  'processing',
#  'produce',
#  'producing',
#  'product',
#  'production',
#  'products',
#  'professional',
#  'professionals',
#  'profile',
#  'programme',
#  'programmes',
#  'programming',
#  'progress',
#  'progression',
#  'progressive',
#  'project',
#  'projects',
#  'promote',
#  'promoting',
#  'property',
#  'prospects',
#  'protection',
#  'proven',
#  'provide',
#  'provided',
#  'provider',
#  'providers',
#  'providing',
#  'provision',
#  'public',
#  'purpose',
#  'qualification',
#  'qualifications',
#  'qualified',
#  'quality',
#  'queries',
#  'quickly',
#  'range',
#  'rapidly',
#  'rate',
#  'rates',
#  'real',
#  'receive',
#  'receiving',
#  'recent',
#  'recognised',
#  'recommend',
#  'record',
#  'records',
#  'recruit',
#  'recruiting',
#  'recruitment',
#  'reference',
#  'references',
#  'region',
#  'registered',
#  'registration',
#  'regular',
#  'regulations',
#  'regulatory',
#  'related',
#  'relation',
#  'relationship',
#  'relationships',
#  'relevant',
#  'reliable',
#  'report',
#  'reporting',
#  'reports',
#  'reputable',
#  'reputation',
#  'requested',
#  'require',
#  'required',
#  'requirement',
#  'requirements',
#  'requires',
#  'research',
#  'residential',
#  'residents',
#  'resources',
#  'respond',
#  'response',
#  'responsibilities',
#  'responsibility',
#  'responsible',
#  'restaurant',
#  'results',
#  'retail',
#  'return',
#  'review',
#  'reviews',
#  'rewarding',
#  'risk',
#  'role',
#  'roles',
#  'rosette',
#  'rota',
#  'running',
#  'safe',
#  'safeguarding',
#  'safety',
#  'salary',
#  'sales',
#  'satisfaction',
#  'scheme',
#  'schemes',
#  'school',
#  'schools',
#  'search',
#  'section',
#  'sector',
#  'sectors',
#  'secure',
#  'security',
#  'seeking',
#  'selection',
#  'selling',
#  'send',
#  'sending',
#  'senior',
#  'server',
#  'service',
#  'services',
#  'setting',
#  'share',
#  'shift',
#  'shifts',
#  'short',
#  'significant',
#  'similar',
#  'site',
#  'sites',
#  'situated',
#  'sized',
#  'skill',
#  'skilled',
#  'skills',
#  'small',
#  'smooth',
#  'social',
#  'software',
#  'solid',
#  'solution',
#  'solutions',
#  'solving',
#  'sound',
#  'south',
#  'specialist',
#  'specific',
#  'specifically',
#  'specification',
#  'specifications',
#  'staff',
#  'stage',
#  'stakeholders',
#  'standard',
#  'standards',
#  'star',
#  'start',
#  'starting',
#  'status',
#  'step',
#  'strategic',
#  'strategies',
#  'strategy',
#  'strong',
#  'structure',
#  'structured',
#  'subject',
#  'succeed',
#  'success',
#  'successful',
#  'suit',
#  'suitable',
#  'supervision',
#  'supervisory',
#  'supplier',
#  'suppliers',
#  'supply',
#  'support',
#  'supported',
#  'supporting',
#  'supportive',
#  'surrey',
#  'surrounding',
#  'system',
#  'systems',
#  'taking',
#  'talented',
#  'target',
#  'targets',
#  'tasks',
#  'teacher',
#  'teachers',
#  'teaching',
#  'team',
#  'teams',
#  'technical',
#  'technically',
#  'technician',
#  'techniques',
#  'technologies',
#  'technology',
#  'telephone',
#  'temporary',
#  'term',
#  'terms',
#  'test',
#  'testing',
#  'thinking',
#  'time',
#  'timely',
#  'times',
#  'title',
#  'today',
#  'tools',
#  'totaljobs',
#  'touch',
#  'track',
#  'train',
#  'trained',
#  'training',
#  'transport',
#  'travel',
#  'treatment',
#  'type',
#  "uk's",
#  'understand',
#  'understanding',
#  'undertake',
#  'undertaking',
#  'uniform',
#  'unique',
#  'unit',
#  'unsuccessful',
#  'urgently',
#  'user',
#  'users',
#  'vacancies',
#  'vacancy',
#  'valid',
#  'varied',
#  'variety',
#  'vehicle',
#  'verbal',
#  'view',
#  'visit',
#  'visits',
#  'volume',
#  'website',
#  'week',
#  'weekend',
#  'weekends',
#  'weekly',
#  'weeks',
#  'west',
#  'whilst',
#  'white',
#  'wide',
#  'willingness',
#  'windows',
#  'winning',
#  'word',
#  'work',
#  'worked',
#  'worker',
#  'workers',
#  'working',
#  'workload',
#  'workplace',
#  'works',
#  'world',
#  'writing',
#  'written',
#  'year',
#  'years',
#  'yorkshire',
#  'young'}

# %%
# running the purifier funtion to remove highFreq tokens
tokenised = purifier(tokenised,highFreq)

# %% [markdown]
# - Now, I'm going to create a new list of words after highFreq words are removed

# %%
HighFreqRemoved_words = list(chain.from_iterable([word for word in job] for job in tokenised))
HighFreqRemoved_vocab = set(HighFreqRemoved_words)

# %% [markdown]
# ** This is an extra checkpoint to monitor the progress of purification

# %%
print(f"Length of words: {len(stop_wrds_removed_words)}")
print(f"Length of vocab: {len(stop_wrds_removed_vocab)}")
print(f"Length of LowFreqRemoved_Words: {len(LowFreqRemoved_Words)}")
print(f"Length of LowFreqRemoved_vocab: {len(LowFreqRemoved_vocab)}")
print(f"Length of HighFreqRemoved_words: {len(HighFreqRemoved_words)}")
print(f"Length of HighFreqRemoved_vocab: {len(HighFreqRemoved_vocab)}")
# Out:
# Length of words: 474345
# Length of vocab: 18619
# Length of LowFreqRemoved_Words: 465779
# Length of LowFreqRemoved_vocab: 10053
# Length of HighFreqRemoved_words: 126491
# Length of HighFreqRemoved_vocab: 9103

# %% [markdown]
# ### vocab.txt

# %%
HighFreqRemoved_vocab = list(HighFreqRemoved_vocab)

# %%
# list of final vocabs
vocab = {HighFreqRemoved_vocab[i]:i for i in range(0,len(HighFreqRemoved_vocab))}

# %%
# building a function to create th vocab.txt file meeting the task's requirements
def vaocab_output(file):
    with open (file, "a") as f:
        for key in sorted(vocab.keys()):
            f.write("%s:%s\n" % (key, vocab[key]))

# %%
# calling the function and build the file
vaocab_output("vocab.txt")

# %% [markdown]
# ### Parser.txt

# %%
data = {}
id = None
with open('data.txt', 'r',encoding="utf8") as f:
    for i, line in enumerate(f): # create the iteration in the range of imported file's length
        line = line.lower() 
        line = line.strip()
        if not line:
            continue
        section = line.split(':')[0] # define 'section' as a method to manupilate each line based on how the line begins
        content = ':'.join(line.split(':')[1:]).strip() # define 'content' a method to capture tokens
        if section == 'id': # id section:
            if id: # Error handle if theres some bad formatting: multiple ids
                raise ValueError('unable to parse file at line %d, multiple ids' % i)
            id = content[1:] # capture the job id
            if id in data.keys():# Error handle if theres some bad formatting: duplicates
                raise ValueError('unable to parse file at line %d, duplicate id' % i)
        elif section == 'description': #capture job description per each job ad
            if not id:# Error handle if theres some bad formatting: missing id
                raise ValueError('unable to parse file at line %d, missing id' % i)
            content = pattern.findall(line)
            content = [value for value in content if len(value) > 3] # remove short character token
            content = [value for value in content if value not in stopwordsset] # remove stopwords
            content = [value for value in content if value not in once_only] # remove lowFreq token
            content = [value for value in content if value not in highFreq] # remove highFreq tokens
            data[id] = content # creates data dictionary
            id = None
        elif section == 'title': # if the line start with 'title' do nothing
            continue
        else:
            raise ValueError('unable to parse file at line %d, unexpected section name' % i)

# %%
# Build output file:

with open('sparse.txt',"w") as f:
    for jobID,content in data.items(): # go through data dictionary created in the last block
        fd_parse = FreqDist(content) # count number of times each token occured in the same job ad
        tmp = "" # create a placeholder for word_index:word_freq
        for (x,y) in fd_parse.items(): # iterate through each frequencies
            tmp += f"{vocab[x]}:{y}," # build the dictionary of word_index:word_freq in the placeholder
        f.write(f"#{jobID},{tmp[:-1]}\n") # write in the file line by line

# %% [markdown]
# ---end---
