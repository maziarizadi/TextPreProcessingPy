# %% [markdown]
# Maziar Izadi
#
# Data wrangling in Python

# %%
# Import required libraries

# Regular Expressions (REGeX)
import re
from nltk.probability import *

# Natural Language Toolkit
import nltk

# Functions creating iterators for efficient looping
import itertools
from itertools import chain
from itertools import groupby

# Convert a collection of text documents to a matrix of token counts
from sklearn.feature_extraction.text import CountVectorizer

# %%
# open the file and read the contents
data = []

# make sure you define the encoding format otherwise you might get this error: 
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 260893: character maps to <undefined>
with open('data.txt', encoding="utf8") as f:
    data = f.read().lower() # read the content and lower the letters (for consistency)

# %%
# make a pattern for REGEX to find and keep matching words only
pattern = re.compile(r"[a-zA-Z]+(?:[-'][a-zA-Z]+)?") 

# tokenise the words: match the pattern to file's content and tokenize the content
tokenised = pattern.findall(data)

# %%
tokenised_len = len(tokenised)
indexes = [i for i, v in enumerate(tokenised) if v=='id' and i+1 < tokenised_len and tokenised[i+1]=='title']

# %%
# from itertools recipes
def pairwise(iterable, fillvalue=None):
    """
       This function iterates through the list of tokens and 
       creates sub list to include tokens related to one job ad only
    """
    a, b = iter(iterable), iter(iterable)
    next(b, None)
    return itertools.zip_longest(a, b, fillvalue=fillvalue)

# pairwise based on indexes in the last block and store in the 'tokenised' as a list
tokenised = [tokenised[i:j] for i,j in pairwise(indexes)]

# %% [markdown]
# - Exclude words less than 3 char:
#
# ** I have kept all the tokens which are more than 2 characters and renamed the rest to 'to_removed
#
# ** "to_remove" is added to "stopwords" list further down

# %%
tokenised = [[word if len(word) > 2 else "to_remove" for word in job] for job in tokenised]

# %% [markdown]
# ### Removing stopwords

# %%
# adding'to_removed' string to the list of stopwords
stopwords = []
with open('stopwords_en.txt',"a") as f:
    f.write("\nto_remove") #\n to shift to next line

# %%
with open('stopwords_en.txt') as f:
    stopwords = f.read().splitlines() #reading stopwords line and create stopwords as a list

# %%
# convert stopwords into set
#Python set is better choice than list. 
# Set runs much faster than lists in terms of searching a large number of hashable items

stopwordsset = set(stopwords)

# %%
def purifier(tokenList,remove_token):
    """
        This function takes two input (list of current tokens and list of tokens to be removed)
        The function converts the list into set to improve the performance
        and return a list of sets each of which include purified tokens
        and remove_token lists are removed
    """
    return [set(word for word in job if word not in remove_token) for job in tokenList]

# %%
# running 'purifier' function
tokenised = purifier(tokenised,stopwordsset)

# %% [markdown]
# You need to remove the words that appear only once in one job advertisement description, save them ( No duplication) as a txt file (refer to the required output). You will need to exclude those words in the generated vocabulary.

# %%
# Using chain() function to join all the words in all the job ads together by making a list
words = list(chain.from_iterable([word for word in job] for job in tokenised))
# convert the list of words into set to remove duplicates and create the set of vocabulary
vocab = set(words)
# passing the words in FreqDisrt() function to cound the number of token
# this function counts the number of times a word occurs in the whole corpus regardless which ad it is in.
fd = FreqDist(words)

# %%
# finding the Less Frequent Tokens.

# create a list of token which have occured more than once
# convert the list into set for performance improvement
once_only = set([k for k, v in fd.items() if v == 1])
# sort the set into alphabetical order
once_only = sorted(once_only)

set(once_only)
# Out:
# {'sift',
#  'experiencework',
#  'cyps',
#  'securityengineer',
#  'beech',
#  'domaindriven',
#  'clientbase',
#  'harryannapurnait',
#  'musculoskeletal',
#  'stuides',
#  'prelegal',
#  'requiredskills',
#  'traumatic',
#  'gunton',
#  'counseling',
#  'sherburn',
#  'desperate',
#  'localisation',
#  'cemli',
#  'elaborating',
#  'bullcustomer',
#  'compressor',
#  'cont',
#  'technicalforderecruitment',
#  'implementationsexperience',
#  'micros',
#  'snack',
#  'roughly',
#  'apartments',
#  'ccd',
#  "criteria's",
#  'texile',
#  'yateley',
#  'membersimplement',
#  'serviceusers',
#  'gatewaypersonnel',
#  'unauthorized',
#  'accpac',
#  'jakarta',
#  'marsden',
#  'buzzy',
#  'booster',
#  'semiliquid',
#  'applicationsplease',
#  'corrections',
#  'electronicspower',
#  'illess',
#  'issuesyour',
#  'nopcommerce',
#  'enriched',
#  'generalmanagerbrilliantcompanyeastlondon',
#  'psychotherapy',
#  'prestage',
#  'sdm',
#  'selfregulated',
#  'scameronqmu',
#  'bpas',
#  'afx',
#  'barcelona',
#  'derhamadriasolutions',
#  'partially',
#  'barney',
#  'aquillon',
#  'opensource',
#  'predicted',
#  'strategists',
#  'asapecommerce',
#  'etsi',
#  'jurisdictions',
#  'cncmillersetteroperator',
#  'rentalcars',
#  'ascribed',
#  'dispenser',
#  'qualityassistant',
#  'reinsurers',
#  'salarysupport',
#  'outright',
#  'beneficialsenior',
#  'isas',
#  'postdelivery',
#  'projectsfamiliar',
#  'successfactors',
#  'solutionsexperience',
#  'exhausts',
#  'exteachers',
#  'bonusonline',
#  'lorraine',
#  'neat',
#  'wastes',
#  'poise',
#  'hartlepool',
#  'discus',
#  'highlycompetitive',
#  'deafness',
#  'moston',
#  'pocess',
#  'daykey',
#  'timemanagement',
#  'jsf',
#  'preand',
#  'javamicrosoft',
#  'middx',
#  'ledbury',
#  'markview',
#  'arrows',
#  'signedoff',
#  'ontargetearnings',
#  'bonza',
#  'formalisation',
#  'multimeters',
#  'mwh',
#  'autotrade',
#  'scrambled',
#  'middletier',
#  'tilt',
#  'qualificationcreation',
#  'advertisers',
#  'workshopsproducing',
#  'callin',
#  'requrirments',
#  'mutli',
#  'neartoeye',
#  'fazed',
#  'smethwick',
#  'heartland',
#  'objectorientateddesign',
#  'barton',
#  'electricallybiasedmaintenanceengineer',
#  'bensan',
#  'prestfield',
#  'rosettewindsorqualitygroup',
#  'bmsserviceengineer',
#  'anerley',
#  'unvalidated',
#  'remediate',
#  'anticipatory',
#  'hearted',
#  'decommissioned',
#  'ollow',
#  'norther',
#  'facades',
#  'euda',
#  'ipaf',
#  'fulfils',
#  'internationallyrecognised',
#  'riser',
#  'spackman',
#  'javaspringdevelopersecommercedevelopmentnorthampton',
#  'direkt',
#  'goldmine',
#  'skillsaerospace',
#  'wellmanaged',
#  'xforms',
#  'neighbouring',
#  'chingford',
#  'lambert',
#  'subscriptions',
#  'flue',
#  'lcms',
#  'ltc',
#  'sealing',
#  'jockey',
#  'liable',
#  'rigourous',
#  'nant',
#  'cds',
#  'interlock',
#  'serviceengineerfiresecuritynwyorkshire',
#  'traineegraduateaspnetdeveloper',
#  'dampers',
#  'captor',
#  'mitchell',
#  'servicesregulations',
#  'gloucesteryou',
#  'filings',
#  'seniorbmscontrolsengineer',
#  'replicated',
#  "programme's",
#  'chiamaka',
#  'transportations',
#  'detaili',
#  'ija',
#  'ceilings',
#  'salesmanager',
#  'efficie',
#  'customerservicesrepresentative',
#  'fiver',
#  'starhotelto',
#  'taxonomy',
#  'viewed',
#  'cooks',
#  'blasting',
#  'woodhays',
#  'smartdevice',
#  'jag',
#  'decking',
#  'valuesorientated',
#  'environmentfamiliarity',
#  'carmarthenshire',
#  'kudos',
#  'tht',
#  'mammographer',
#  'llpg',
#  'ivf',
#  'registerednurse',
#  'civic',
#  'feburary',
#  'documentationset',
#  'recreations',
#  'maintenence',
#  'packers',
#  'skillsfamiliarity',
#  'orbital',
#  'intrested',
#  'divides',
#  'seniorsouschefhighendcountryhousehotelawardwinningdining',
#  'grocockrandstadfp',
#  'pcdu',
#  'plush',
#  'ased',
#  'solids',
#  'ethnicities',
#  'rainwater',
#  'impede',
#  'scottprecisionrecruitment',
#  'followers',
#  'jobyou',
#  'multitalented',
#  'enterpriseguide',
#  'facilitiesmanager',
#  'karl',
#  'serviceengineerhighpressuresystems',
#  'ann',
#  'concierge',
#  'folowing',
#  'processingschematic',
#  'electricalengineerashford',
#  'robin',
#  'wrist',
#  'responsibiliities',
#  'caglach',
#  'rcorkettmedicorglobal',
#  'duplicate',
#  'subdivision',
#  'getty',
#  'doubles',
#  'scandinavia',
#  'thamesworking',
#  'withstand',
#  'abdominal',
#  'downtrack',
#  'unresolved',
#  'bladesystem',
#  'hadoopsalary',
#  'holmes',
#  'priceless',
#  'blanking',
#  'developersmanagement',
#  'telecomm',
#  'striaght',
#  'lincs',
#  'biologists',
#  'eso',
#  'deansgate',
#  'elmet',
#  'fellowship',
#  'julian',
#  'analysisknowledge',
#  'eigrp',
#  'wing',
#  'smg',
#  "legislation's",
#  'trustworth',
#  'executions',
#  'dismissal',
#  'uslisted',
#  'pour',
#  'mediumcomplex',
#  'fronted',
#  'grammatically',
#  'testingprovide',
#  'removes',
#  'henleyonthames',
#  'retros',
#  'abilitiesfinancial',
#  'tomato',
#  'buffers',
#  'avaliable',
#  'icheme',
#  'meningitis',
#  'leachate',
#  'nicola',
#  'perfmon',
#  'maintenanceandrepairengineer',
#  'mbo',
#  'esteem',
#  'systemsdesirableo',
#  'productionengineeringmanager',
#  'crbs',
#  'reagents',
#  'resorts',
#  'rcslt',
#  'regimented',
#  'shenfield',
#  'pastdue',
#  'counting',
#  'applicationlevel',
#  'jse',
#  'privilegecard',
#  'neal',
#  'cox',
#  'vjopusrsaptrackco',
#  'puppies',
#  'generalmanagerbrilliantcompanynorthlondon',
#  'bullqualified',
#  'feisty',
#  'weakness',
#  'lathese',
#  'brains',
#  'quantitive',
#  'beed',
#  'qualificationseffective',
#  'coverageyou',
#  'redemptions',
#  'panelwireman',
#  'incinerator',
#  'dayweeksliveinavailable',
#  'benefitsi',
#  'drbs',
#  'commischefoutstandingfinediningrestaurantservicecharge',
#  'rebranded',
#  'wheeled',
#  'environmentrelease',
#  'workplease',
#  'cor',
#  'acl',
#  'rationalised',
#  'chefdepartiedorking',
#  'fpgascoding',
#  'closelyknit',
#  'buoyant',
#  'brunch',
#  'travelled',
#  'embryology',
#  'paignton',
#  'ypd',
#  'talbots',
#  'hydropower',
#  'lcr',
#  'westhays',
#  'crisa',
#  'technicalsalesengineerelectromechanical',
#  'papworth',
#  'lined',
#  'aak',
#  'hosptial',
#  'zeal',
#  'guarantor',
#  'draws',
#  'solutionsecommerce',
#  'crmumlsharepointsasweblogictibcohybrisappropriate',
#  'oawareness',
#  'epm',
#  'dmcc',
#  'xfs',
#  'secretaries',
#  'originated',
#  'policiesessential',
#  'reallocation',
#  'multithreader',
#  'iday',
#  'gastrostomies',
#  'winders',
#  'downham',
#  'visitswide',
#  'promised',
#  'theukand',
#  'crash',
#  'rerefurbishment',
#  'tyres',
#  'verma',
#  'landfill',
#  'curtains',
#  'volunteer',
#  'aamm',
#  'carand',
#  'transmissions',
#  'pakcage',
#  'goahead',
#  'handtoeye',
#  'workscopes',
#  'alison',
#  'crrq',
#  'winterhalter',
#  'bbpressbrakecov',
#  'lenarm',
#  'priding',
#  'techical',
#  'burford',
#  'multiawardwinning',
#  'deleting',
#  'functionsdesired',
#  'newcomer',
#  'cheese',
#  'cookpertemps',
#  'lineups',
#  'managementoserver',
#  'iprocurement',
#  'ssms',
#  'obiee',
#  'hythe',
#  'iqx',
#  'qualms',
#  'sparx',
#  'minibus',
#  'exterity',
#  'harrison',
#  'intrinsic',
#  'greenhat',
#  'staffnurse',
#  'inreach',
#  'millage',
#  'calibrationtechnician',
#  'bullexperience',
#  'warner',
#  'quarkxpress',
#  'riskbased',
#  'movies',
#  'tennis',
#  'eyecare',
#  'annumdate',
#  'flagging',
#  'reevaluation',
#  'webdesigner',
#  'jenrick',
#  'mediumterm',
#  'bredbury',
#  'addittion',
#  'londonare',
#  'cooperswanstaff',
#  'manintenance',
#  'gammon',
#  'smbu',
#  'eviction',
#  'gias',
#  'kim',
#  'additonal',
#  'sixmonthly',
#  'czech',
#  'ystrad',
#  'icaew',
#  'handles',
#  'mcu',
#  'addins',
#  'rdlineinfrastructuresupportanalystlondon',
#  'banquetchefcountryhousehotelawardwinningvenuelivein',
#  'resp',
#  'beamed',
#  'jobid',
#  'meica',
#  'duplex',
#  'concordion',
#  'byrne',
#  "member's",
#  'ptto',
#  'artistic',
#  'opthalmology',
#  'seeaking',
#  'lifeless',
#  'rajzest',
#  'forwardmoving',
#  'cogs',
#  'noninfrastructure',
#  'seniorelectricalprojectmanager',
#  'performancetestdevelopernetc',
#  'gitnice',
#  'metalpolisher',
#  'torbay',
#  'bowers',
#  'unallocated',
#  'profilers',
#  'javao',
#  'acsl',
#  'tmsds',
#  'internetbased',
#  'fastener',
#  'agreenfieldenvironment',
#  'looms',
#  'embraced',
#  'hopping',
#  'cforesponsible',
#  'goldengate',
#  'quinquennial',
#  'preexisting',
#  'timplus',
#  'faststream',
#  'amber',
#  'beccles',
#  'levelan',
#  'ddms',
#  'tranquil',
#  'weaknessesdriving',
#  'dnc',
#  'accent',
#  'veterinary',
#  'natasha',
#  'businessfulham',
#  'countless',
#  'marginal',
#  'nonfault',
#  'nsi',
#  'hoiuejuselbyjenningsaptrackcouk',
#  'tesol',
#  'foreseeable',
#  'leclade',
#  'adswood',
#  'toronto',
#  'firstlevel',
#  'serverjavascript',
#  'managersrequiredupnationwide',
#  'inspectio',
#  'njmwzdg',
#  'corners',
#  'borden',
#  "dealership's",
#  'joeexactsourcing',
#  'forproducing',
#  'kthprtalent',
#  'projectrelated',
#  'woodstock',
#  'casey',
#  'macbook',
#  'juniorsouschefawardwinninghotelhighvolumekitchenoperation',
#  'dsps',
#  'acarrstrgroup',
#  'footed',
#  'interpersonally',
#  'hucknall',
#  'rsk',
#  'technologiesexperience',
#  'intriguing',
#  'glenrothes',
#  'clearer',
#  'saved',
#  'deputies',
#  'turbomachinery',
#  'inserting',
#  'aspectsocompletes',
#  'knowleadge',
#  'dfsa',
#  'tribal',
#  "holder's",
#  'digi',
#  'marketinganalystsas',
#  'brooks',
#  'workbench',
#  'softwareclient',
#  'vacanciesplease',
#  'bpc',
#  'electricaldesignengineerrail',
#  'sprayer',
#  'turrett',
#  'humus',
#  'programmingthe',
#  'lamperl',
#  'mapperley',
#  'carecoordinator',
#  'instructors',
#  'matchtech',
#  'meads',
#  'marie',
#  'processdriven',
#  'poke',
#  'hybris',
#  'composing',
#  'jap',
#  'careathome',
#  'taxfree',
#  'contactless',
#  'incisus',
#  'distributes',
#  'kace',
#  'crmdue',
#  'markitwire',
#  'remmingtontheimsgroup',
#  'kidde',
#  'objectivity',
#  'stewarts',
#  'braille',
#  'inns',
#  'skillsextensive',
#  'timelimited',
#  'conveyancing',
#  'openminded',
#  'doctrine',
#  'paneuropean',
#  'junos',
#  'caremark',
#  'kpbarnetkareplus',
#  'structuralengineertechnician',
#  'cognizant',
#  'beeritnmark',
#  'rigsbill',
#  'katybeerecruitment',
#  'appplications',
#  'morethe',
#  'generalmanagerfoodledcountrypub',
#  'gartner',
#  'japanese',
#  'responsibilties',
#  'lgps',
#  'customercentric',
#  'ingloucesterthat',
#  'diffusing',
#  'headchefawardwinningcountryinntopqualitydininglivein',
#  'tyrrell',
#  'inducting',
#  'checkyou',
#  'fare',
#  'prairie',
#  'heiman',
#  'discovering',
#  'busines',
#  'developmentmanageragile',
#  'hydraulicsassemblyfittertechnicianmachinedevelopmentengineer',
#  'admineclypserecruitment',
#  'etiquette',
#  'allocations',
#  "legality's",
#  'davyhulme',
#  'elevating',
#  'ocp',
#  'catch',
#  'das',
#  'nep',
#  'hysteroscopy',
#  'solo',
#  'puppy',
#  'excite',
#  'universes',
#  'kategimrfood',
#  'onhold',
#  'branching',
#  'developercrystal',
#  'slowing',
#  'ibosh',
#  'ccws',
#  'welsh',
#  'nondoms',
#  'immediacy',
#  'clusterware',
#  'vloume',
#  'representives',
#  'ensuing',
#  'ohio',
#  'contactors',
#  "diploma's",
#  'pragmatism',
#  'hydraulicsengineer',
#  'serco',
#  'binary',
#  'thai',
#  'orbit',
#  'travail',
#  'unicode',
#  'oordinate',
#  'hydraulicsystems',
#  'bodi',
#  'designsuitable',
#  'kitbag',
#  'compiler',
#  'environmentsundertake',
#  'netherton',
#  'moj',
#  'suspects',
#  'clientraised',
#  'worried',
#  'autotrack',
#  'interworking',
#  'itsystemsadministrationvmwareandwindows',
#  'chislehurst',
#  'converter',
#  'dronfield',
#  'recall',
#  'permenant',
#  'nottinghamare',
#  'austempering',
#  'neverending',
#  'nooks',
#  'detached',
#  'imminentlyfunctional',
#  'aper',
#  'ideals',
#  'railrelated',
#  'esmitheclypserecruitment',
#  'engineeringstoresmanagerandstorescoordinatorsderby',
#  'lowsecure',
#  'progressprepare',
#  'savouries',
#  'pmb',
#  'sufficiency',
#  'turret',
#  'proportional',
#  'ehv',
#  'notebooks',
#  'partieyou',
#  'inbuilt',
#  'includeassisting',
#  'atlas',
#  'sweep',
#  'allocates',
#  'informationnet',
#  'milage',
#  'pcp',
#  'burrelton',
#  'mainframes',
#  'poweredge',
#  'residentail',
#  'londonduration',
#  'certifiedstrong',
#  'heattreatments',
#  'engineerelectrical',
#  'businessdevelopmentmanagerittelecommunicationsote',
#  'misdescriptions',
#  'vcenter',
#  "company'sapplications",
#  "qt's",
#  'cpos',
#  'procurements',
#  'dustbin',
#  'cefa',
#  'playstationvita',
#  'availabledays',
#  'didn',
#  'mobilise',
#  'forecasted',
#  'muratsubaki',
#  'rushmoor',
#  'banked',
#  'grafton',
#  'strat',
#  'quegangappersonnel',
#  'aoi',
#  "someone's",
#  'thatcham',
#  'experiencejob',
#  'disseminating',
#  'dayday',
#  'korn',
#  'millturn',
#  'nbsplingfield',
#  'gyneacology',
#  'jnrnetdeveloper',
#  'penchant',
#  'secondface',
#  'vdi',
#  'grc',
#  'mns',
#  'highintegrity',
#  'pearsonocccomputing',
#  'incentivising',
#  'internallyraised',
#  'kdata',
#  'workingopus',
#  'forwe',
#  'mmch',
#  'requiredsubstantial',
#  'lookalike',
#  'barristers',
#  'resultsfocused',
#  'chefdepartienorfolkliveinupto',
#  'mezzo',
#  'andknowledge',
#  'chefdepartiemichelin',
#  'yearsall',
#  'succeeded',
#  'masonic',
#  'gaze',
#  'stenton',
#  'palate',
#  'huntress',
#  'advantange',
#  'dotnetnuke',
#  'refinancings',
#  'gun',
#  'partnerthis',
#  'vmstat',
#  'seater',
#  'terminals',
#  'roseete',
#  'sourdoughs',
#  'flexiblity',
#  'commischefwellrespectedhotelallfreshfoodlivein',
#  'pfi',
#  'fence',
#  'adopts',
#  'aerotek',
#  'extents',
#  'dali',
#  'inst',
#  'opportuities',
#  'patientcentred',
#  'stemmed',
#  'torch',
#  'carework',
#  'shadows',
#  'powercentre',
#  'synchronizer',
#  'cutter',
#  'motorola',
#  'adl',
#  'transducers',
#  'attendmandatory',
#  'pushes',
#  'rome',
#  'cwinstanleycarewatch',
#  'legislator',
#  "supply's",
#  'senoir',
#  'tped',
#  'groovy',
#  'demodulation',
#  'beware',
#  'arbitrage',
#  'confectionary',
#  'thiswe',
#  'vliw',
#  'avinstallationengineersmarthomecinema',
#  'uiuxdesignerdeveloper',
#  'confidences',
#  'customerescalated',
#  'toolpost',
#  'accommodating',
#  'egulated',
#  'ddl',
#  'salespeople',
#  'customized',
#  'businesslike',
#  'haptic',
#  'sitemaps',
#  'panasonic',
#  'kbp',
#  'issueswork',
#  'filler',
#  'dely',
#  'mckerr',
#  'shiftengineerperm',
#  'fnol',
#  'timekeeper',
#  'chefdepartiehotelofferingbistrostyledininglivein',
#  'inpossession',
#  'wtl',
#  'bother',
#  'janaury',
#  'deepwater',
#  'hurry',
#  'purchaser',
#  'hdl',
#  'piggy',
#  'immobile',
#  'oundle',
#  'eveloping',
#  'mancheste',
#  'constructor',
#  'multiprofessional',
#  'elogantmrec',
#  'pressbraking',
#  'ajay',
#  'biles',
#  'brownharvardbrown',
#  'solutionoresponsible',
#  'programmingworking',
#  'playstation',
#  'wix',
#  'mobberley',
#  'quickest',
#  'bcobs',
#  'parte',
#  'actionmonitor',
#  'optimiser',
#  'exprience',
#  'souschefpremiumrestaurantgroupaberdeen',
#  'deductions',
#  'datasheets',
#  'optimisationstrong',
#  'teamsbudgets',
#  'tenure',
#  'endsalary',
#  'carriageway',
#  'yearsexperience',
#  'originations',
#  'drupalif',
#  'siteapplicants',
#  'assistantmanagerstalbansfantasticopportunity',
#  'souschefstablefreshfoodpubfreeliveingoodtips',
#  'traveltradesalesmanager',
#  'salessupportmanagerpresalesprojectmanagement',
#  'suiteadvanced',
#  'wiping',
#  'commischefrefurbishedrestaurantallfreshproduce',
#  'chloe',
#  'rsh',
#  'radiators',
#  'vocal',
#  'picu',
#  'familar',
#  'industrialrefrigerationengineer',
#  'iop',
#  'staffto',
#  'chefdepartiemodernhighvolumehotelfreshfoodgoodtips',
#  'staging',
#  'contextual',
#  'fractures',
#  'cen',
#  'sacs',
#  'methuen',
#  'watches',
#  'gardening',
#  "portfolio's",
#  'graduatesstart',
#  'chefdepartiebusybrasseriestylerestaurantallfreshfood',
#  'barrier',
#  'hes',
#  'electricalbuildingservicesengineer',
#  'ntbackup',
#  'fighter',
#  'nowto',
#  'nbspare',
#  'bilston',
#  'brighter',
#  'vague',
#  'woodend',
#  'homer',
#  'isqtb',
#  'archives',
#  'elect',
#  'micheldean',
#  'portlets',
#  'aegon',
#  'australasia',
#  'projectseniorquantitysurveyor',
#  'chefdepartiebrasseriestylerestauranthighqualityvenue',
#  'toolssets',
#  "javascripti'd",
#  'jargon',
#  'taster',
#  "england's",
#  'carole',
#  'highlyeducated',
#  'unblocking',
#  'dii',
#  'insouth',
#  'nonproduct',
#  'audix',
#  'opinions',
#  'partierequired',
#  'maidsone',
#  'systemsyou',
#  'questionnaire',
#  'headhunters',
#  'hml',
#  'deprived',
#  'vaccines',
#  'businessesresponsible',
#  'knx',
#  'risby',
#  'gradual',
#  'sheilds',
#  'blocking',
#  'commercework',
#  'gatheringthis',
#  'llp',
#  'ourlondonteam',
#  'barlow',
#  'postgrad',
#  'reforms',
#  'experienceproven',
#  'relexed',
#  'cateys',
#  'ollerton',
#  'chapeltown',
#  'scaffolds',
#  'gantry',
#  'empire',
#  'exchanges',
#  'selfassessment',
#  'excelletn',
#  'caps',
#  'ospf',
#  'managerare',
#  'warnings',
#  'wimes',
#  'affiliation',
#  'interpretations',
#  'wormelow',
#  'cdl',
#  'ipcores',
#  'cdrl',
#  'toiletting',
#  'replanning',
#  ...}

# %% [markdown]
# ### lowFreq.txt
# - Saving the sorted list of the words that appear only once in one job advertisement description to a file

# %%
out_file = open("lowFreq.txt", 'w')
for d in once_only:
    out_file.write(''.join(d) + '\n')
out_file.close()

# %%
# At this stage, I repead the same steps above
# However, this time the intention is to find the highFreq words
# start from removing lowFreq tokens from the list of tokens

tokenised = purifier(tokenised,once_only)

# %% [markdown]
# - Now, I'm going to create a new list of words after once_only words are removed

# %%
words2 = list(chain.from_iterable([word for word in job] for job in tokenised))
vocab2 = set(words2)
fd2 = FreqDist(words2)

# %%
highFreq = set([k for k, v in fd2.items() if v > 100])

# %% [markdown]
# ### highFreq.txt
# - Saving the sorted list of high frequent words that appear in more than 100 job advertisement description to a file

# %%
out_file = open("highFreq.txt", 'w')
for d in highFreq:
    out_file.write(''.join(d) + '\n')
out_file.close()

# %%
set(highFreq)
# Out:
# {'ability',
#  'accept',
#  'access',
#  'accommodation',
#  'accordance',
#  'account',
#  'accounting',
#  'accounts',
#  'accurate',
#  'achieve',
#  'achieving',
#  'act',
#  'acting',
#  'active',
#  'actively',
#  'activities',
#  'activity',
#  'acts',
#  'addition',
#  'additional',
#  'address',
#  'administration',
#  'adults',
#  'advanced',
#  'advantage',
#  'advantageous',
#  'advertised',
#  'advice',
#  'age',
#  'agencies',
#  'agency',
#  'agile',
#  'agreed',
#  'aim',
#  'allowance',
#  'alongside',
#  'alternatively',
#  'ambitious',
#  'analysis',
#  'analyst',
#  'analytical',
#  'annual',
#  'annum',
#  'applicant',
#  'applicants',
#  'application',
#  'applications',
#  'apply',
#  'applying',
#  'appointments',
#  'approach',
#  'architecture',
#  'area',
#  'areas',
#  'arisen',
#  'asap',
#  'asp',
#  'aspects',
#  'assess',
#  'assessment',
#  'assessments',
#  'assignments',
#  'assist',
#  'assistance',
#  'assistant',
#  'assistants',
#  'assisting',
#  'associates',
#  'assurance',
#  'asylum',
#  'attend',
#  'attention',
#  'attitude',
#  'attributes',
#  'audits',
#  'authority',
#  'automotive',
#  'availability',
#  'award',
#  'aware',
#  'awareness',
#  'back',
#  'background',
#  'bank',
#  'base',
#  'based',
#  'basic',
#  'basis',
#  'behalf',
#  'behaviour',
#  'beneficial',
#  'benefit',
#  'benefits',
#  'birmingham',
#  'bonus',
#  'brand',
#  'brown',
#  'budget',
#  'build',
#  'building',
#  'built',
#  'business',
#  'busy',
#  'button',
#  'call',
#  'calls',
#  'candidate',
#  'candidates',
#  'capable',
#  'capacity',
#  'car',
#  'care',
#  'career',
#  'carers',
#  'caring',
#  'carry',
#  'case',
#  'cases',
#  'caterer',
#  'catering',
#  'central',
#  'centre',
#  'challenge',
#  'challenging',
#  'chance',
#  'change',
#  'check',
#  'checks',
#  'chef',
#  'chefs',
#  'children',
#  'choice',
#  'circa',
#  'city',
#  'class',
#  'clean',
#  'clear',
#  'click',
#  'clicking',
#  'client',
#  'clients',
#  'clinical',
#  'close',
#  'closely',
#  'code',
#  'colleagues',
#  'comfortable',
#  'commercial',
#  'commission',
#  'commitment',
#  'committed',
#  'communicate',
#  'communication',
#  'communications',
#  'communicator',
#  'community',
#  'commutable',
#  'companies',
#  'company',
#  'competent',
#  'competitive',
#  'complete',
#  'completed',
#  'completion',
#  'complex',
#  'compliance',
#  'components',
#  'comprehensive',
#  'computer',
#  'conditions',
#  'conduct',
#  'confidence',
#  'confident',
#  'configuration',
#  'considered',
#  'consultancy',
#  'consultant',
#  'consultants',
#  'consulting',
#  'contact',
#  'contacted',
#  'continue',
#  'continued',
#  'continuous',
#  'contract',
#  'contracts',
#  'contribute',
#  'control',
#  'controls',
#  'cooking',
#  'copy',
#  'core',
#  'corporate',
#  'cost',
#  'country',
#  'cover',
#  'covering',
#  'cqc',
#  'crb',
#  'create',
#  'creating',
#  'creative',
#  'criteria',
#  'critical',
#  'css',
#  'current',
#  'customer',
#  'customers',
#  'cycle',
#  'daily',
#  'data',
#  'database',
#  'date',
#  'day',
#  'days',
#  'deadlines',
#  'deal',
#  'dealing',
#  'decision',
#  'dedicated',
#  'degree',
#  'deliver',
#  'delivered',
#  'delivering',
#  'delivery',
#  'dementia',
#  'demonstrable',
#  'demonstrate',
#  'department',
#  'departments',
#  'dependent',
#  'depending',
#  'deputy',
#  'description',
#  'design',
#  'designing',
#  'designs',
#  'desirable',
#  'desire',
#  'detail',
#  'detailed',
#  'details',
#  'develop',
#  'developed',
#  'developer',
#  'developers',
#  'developing',
#  'development',
#  'difference',
#  'digital',
#  'dining',
#  'direct',
#  'direction',
#  'directly',
#  'director',
#  'disabilities',
#  'disability',
#  'discipline',
#  'disciplines',
#  'disclosure',
#  'discuss',
#  'diverse',
#  'division',
#  'document',
#  'documentation',
#  'documented',
#  'documents',
#  'domestic',
#  'drawings',
#  'drive',
#  'driven',
#  'driver',
#  'driving',
#  'due',
#  'duties',
#  'duty',
#  'dynamic',
#  'earn',
#  'east',
#  'easy',
#  'eclypse',
#  'eden',
#  'edge',
#  'educated',
#  'education',
#  'effective',
#  'effectively',
#  'efficient',
#  'elderly',
#  'electrical',
#  'eligibility',
#  'eligible',
#  'email',
#  'employee',
#  'employees',
#  'employer',
#  'employment',
#  'enable',
#  'end',
#  'energy',
#  'engineer',
#  'engineering',
#  'engineers',
#  'england',
#  'english',
#  'enhance',
#  'enhanced',
#  'enjoy',
#  'ensure',
#  'ensuring',
#  'enterprise',
#  'enthusiastic',
#  'environment',
#  'environments',
#  'equal',
#  'equality',
#  'equipment',
#  'equivalent',
#  'essential',
#  'establish',
#  'established',
#  'europe',
#  'evenings',
#  'events',
#  'evidence',
#  'excel',
#  'excellence',
#  'excellent',
#  'exceptional',
#  'exciting',
#  'executive',
#  'existing',
#  'expanding',
#  'expansion',
#  'expect',
#  'expectations',
#  'expected',
#  'experience',
#  'experienced',
#  'expert',
#  'expertise',
#  'exposure',
#  'extensive',
#  'external',
#  'eye',
#  'facilities',
#  'facing',
#  'families',
#  'family',
#  'fantastic',
#  'fast',
#  'feedback',
#  'feel',
#  'field',
#  'finance',
#  'financial',
#  'find',
#  'finding',
#  'firm',
#  'fit',
#  'flexibility',
#  'flexible',
#  'focus',
#  'focused',
#  'follow',
#  'food',
#  'form',
#  'forward',
#  'found',
#  'frail',
#  'framework',
#  'free',
#  'fresh',
#  'friday',
#  'friendly',
#  'full',
#  'fully',
#  'fun',
#  'function',
#  'functional',
#  'functions',
#  'future',
#  'gain',
#  'gained',
#  'general',
#  'generation',
#  'generous',
#  'genuine',
#  'give',
#  'giving',
#  'global',
#  'goals',
#  'good',
#  'graduate',
#  'great',
#  'group',
#  'groups',
#  'grow',
#  'growing',
#  'growth',
#  'guidance',
#  'guidelines',
#  'handling',
#  'hands',
#  'happy',
#  'hard',
#  'hardware',
#  'head',
#  'health',
#  'healthcare',
#  'hear',
#  'held',
#  'helping',
#  'high',
#  'highest',
#  'highly',
#  'hold',
#  'holiday',
#  'holidays',
#  'home',
#  'homes',
#  'honest',
#  'hospital',
#  'hotel',
#  'hour',
#  'hourly',
#  'hours',
#  'house',
#  'html',
#  'ideal',
#  'ideally',
#  'ideas',
#  'identify',
#  'identifying',
#  'immediately',
#  'immigration',
#  'implement',
#  'implementation',
#  'implementing',
#  'important',
#  'improve',
#  'improvement',
#  'improvements',
#  'include',
#  'includes',
#  'including',
#  'increase',
#  'independence',
#  'independent',
#  'independently',
#  'individual',
#  'individuals',
#  'induction',
#  'industries',
#  'industry',
#  'information',
#  'infrastructure',
#  'initial',
#  'initiative',
#  'innovative',
#  'installation',
#  'insurance',
#  'integration',
#  'interest',
#  'interested',
#  'internal',
#  'international',
#  'interpersonal',
#  'interview',
#  'interviews',
#  'investment',
#  'involve',
#  'involved',
#  'issues',
#  'java',
#  'javascript',
#  'job',
#  'jobs',
#  'jobseeking',
#  'join',
#  'joining',
#  'junior',
#  'keen',
#  'key',
#  'keywords',
#  'kitchen',
#  'knowledge',
#  'language',
#  'large',
#  'largest',
#  'latest',
#  'lead',
#  'leader',
#  'leadership',
#  'leading',
#  'leads',
#  'learn',
#  'learning',
#  'legislation',
#  'leisure',
#  'letter',
#  'level',
#  'levels',
#  'liaise',
#  'liaising',
#  'liaison',
#  'licence',
#  'life',
#  'lifecycle',
#  'limited',
#  'line',
#  'linux',
#  'literate',
#  'live',
#  'living',
#  'local',
#  'located',
#  'location',
#  'locations',
#  'london',
#  'long',
#  'love',
#  'made',
#  'main',
#  'maintain',
#  'maintained',
#  'maintaining',
#  'maintenance',
#  'major',
#  'make',
#  'making',
#  'manage',
#  'managed',
#  'management',
#  'manager',
#  'managers',
#  'managing',
#  'manchester',
#  'manner',
#  'manufacturing',
#  'market',
#  'marketing',
#  'markets',
#  'match',
#  'matches',
#  'meals',
#  'mechanical',
#  'media',
#  'medical',
#  'medication',
#  'medium',
#  'meet',
#  'meeting',
#  'meetings',
#  'member',
#  'members',
#  'mental',
#  'met',
#  'microsoft',
#  'midlands',
#  'minimum',
#  'mobile',
#  'modern',
#  'monday',
#  'money',
#  'monitor',
#  'monitoring',
#  'month',
#  'monthly',
#  'months',
#  'motivate',
#  'motivated',
#  'move',
#  'multi',
#  'multidisciplinary',
#  'multiple',
#  'national',
#  'nature',
#  'needed',
#  'negotiable',
#  'net',
#  'network',
#  'networking',
#  'newly',
#  'night',
#  'nights',
#  'nmc',
#  'north',
#  'note',
#  'notice',
#  'number',
#  'nurse',
#  'nurses',
#  'nursing',
#  'nvq',
#  'objectives',
#  'offer',
#  'offered',
#  'offering',
#  'offers',
#  'office',
#  'offices',
#  'ongoing',
#  'online',
#  'open',
#  'opening',
#  'operate',
#  'operates',
#  'operating',
#  'operation',
#  'operational',
#  'operations',
#  'opportunities',
#  'opportunity',
#  'order',
#  'organisation',
#  'organisational',
#  'organisations',
#  'organised',
#  'originally',
#  'ote',
#  'outstanding',
#  'overtime',
#  'paced',
#  'package',
#  'packages',
#  'paid',
#  'part',
#  'participate',
#  'partie',
#  'partners',
#  'passion',
#  'passionate',
#  'patient',
#  'patients',
#  'pattern',
#  'patterns',
#  'pay',
#  'pension',
#  'people',
#  'perform',
#  'performance',
#  'period',
#  'permanent',
#  'person',
#  'personal',
#  'personnel',
#  'phone',
#  'php',
#  'physical',
#  'pin',
#  'place',
#  'plan',
#  'planned',
#  'planning',
#  'plans',
#  'plant',
#  'player',
#  'point',
#  'policies',
#  'policy',
#  'portfolio',
#  'position',
#  'positions',
#  'positive',
#  'possess',
#  'post',
#  'posted',
#  'potential',
#  'pound',
#  'practical',
#  'practice',
#  'practices',
#  'preferably',
#  'preferred',
#  'preparation',
#  'prepare',
#  'prepared',
#  'preparing',
#  'present',
#  'presentation',
#  'pressure',
#  'prestigious',
#  'previous',
#  'primary',
#  'principles',
#  'prior',
#  'privacy',
#  'private',
#  'proactive',
#  'problem',
#  'problems',
#  'procedures',
#  'process',
#  'processes',
#  'processing',
#  'produce',
#  'producing',
#  'product',
#  'production',
#  'products',
#  'professional',
#  'professionals',
#  'profile',
#  'programme',
#  'programmes',
#  'programming',
#  'progress',
#  'progression',
#  'progressive',
#  'project',
#  'projects',
#  'promote',
#  'promoting',
#  'property',
#  'prospects',
#  'protection',
#  'proven',
#  'provide',
#  'provided',
#  'provider',
#  'providers',
#  'providing',
#  'provision',
#  'public',
#  'purpose',
#  'qualification',
#  'qualifications',
#  'qualified',
#  'quality',
#  'queries',
#  'quickly',
#  'range',
#  'rapidly',
#  'rate',
#  'rates',
#  'real',
#  'receive',
#  'receiving',
#  'recent',
#  'recognised',
#  'recommend',
#  'record',
#  'records',
#  'recruit',
#  'recruiting',
#  'recruitment',
#  'ref',
#  'reference',
#  'references',
#  'region',
#  'registered',
#  'registration',
#  'regular',
#  'regulations',
#  'regulatory',
#  'related',
#  'relation',
#  'relationship',
#  'relationships',
#  'relevant',
#  'reliable',
#  'report',
#  'reporting',
#  'reports',
#  'reputable',
#  'reputation',
#  'requested',
#  'require',
#  'required',
#  'requirement',
#  'requirements',
#  'requires',
#  'research',
#  'residential',
#  'residents',
#  'resources',
#  'respond',
#  'response',
#  'responsibilities',
#  'responsibility',
#  'responsible',
#  'restaurant',
#  'results',
#  'retail',
#  'return',
#  'review',
#  'reviews',
#  'rewarding',
#  'rgn',
#  'risk',
#  'rmn',
#  'role',
#  'roles',
#  'rosette',
#  'rota',
#  'run',
#  'running',
#  'safe',
#  'safeguarding',
#  'safety',
#  'salary',
#  'sales',
#  'satisfaction',
#  'scheme',
#  'schemes',
#  'school',
#  'schools',
#  'search',
#  'section',
#  'sector',
#  'sectors',
#  'secure',
#  'security',
#  'seeking',
#  'selection',
#  'selling',
#  'send',
#  'sending',
#  'senior',
#  'server',
#  'service',
#  'services',
#  'set',
#  'setting',
#  'share',
#  'shift',
#  'shifts',
#  'short',
#  'significant',
#  'similar',
#  'site',
#  'sites',
#  'situated',
#  'sized',
#  'skill',
#  'skilled',
#  'skills',
#  'small',
#  'smooth',
#  'social',
#  'software',
#  'solid',
#  'solution',
#  'solutions',
#  'solving',
#  'sound',
#  'south',
#  'specialist',
#  'specific',
#  'specifically',
#  'specification',
#  'specifications',
#  'sql',
#  'staff',
#  'stage',
#  'stakeholders',
#  'standard',
#  'standards',
#  'star',
#  'start',
#  'starting',
#  'status',
#  'step',
#  'strategic',
#  'strategies',
#  'strategy',
#  'strong',
#  'structure',
#  'structured',
#  'subject',
#  'succeed',
#  'success',
#  'successful',
#  'suit',
#  'suitable',
#  'supervision',
#  'supervisory',
#  'supplier',
#  'suppliers',
#  'supply',
#  'support',
#  'supported',
#  'supporting',
#  'supportive',
#  'surrey',
#  'surrounding',
#  'system',
#  'systems',
#  'taking',
#  'talented',
#  'target',
#  'targets',
#  'tasks',
#  'teacher',
#  'teachers',
#  'teaching',
#  'team',
#  'teams',
#  'technical',
#  'technically',
#  'technician',
#  'techniques',
#  'technologies',
#  'technology',
#  'telephone',
#  'temporary',
#  'term',
#  'terms',
#  'test',
#  'testing',
#  'thinking',
#  'time',
#  'timely',
#  'times',
#  'title',
#  'today',
#  'tools',
#  'top',
#  'totaljobs',
#  'touch',
#  'track',
#  'train',
#  'trained',
#  'training',
#  'transport',
#  'travel',
#  'treatment',
#  'type',
#  "uk's",
#  'understand',
#  'understanding',
#  'undertake',
#  'undertaking',
#  'uniform',
#  'unique',
#  'unit',
#  'unsuccessful',
#  'urgently',
#  'user',
#  'users',
#  'vacancies',
#  'vacancy',
#  'valid',
#  'varied',
#  'variety',
#  'vehicle',
#  'verbal',
#  'view',
#  'visit',
#  'visits',
#  'volume',
#  'web',
#  'website',
#  'week',
#  'weekend',
#  'weekends',
#  'weekly',
#  'weeks',
#  'west',
#  'whilst',
#  'white',
#  'wide',
#  'willingness',
#  'windows',
#  'winning',
#  'word',
#  'work',
#  'worked',
#  'worker',
#  'workers',
#  'working',
#  'workload',
#  'workplace',
#  'works',
#  'world',
#  'writing',
#  'written',
#  'www',
#  'year',
#  'years',
#  'yorkshire',
#  'young'}

# %%
# running the purifier funtion to remove highFreq tokens
tokenised = purifier(tokenised,highFreq)

# %% [markdown]
# - Now, I'm going to create a new list of words after highFreq words are removed

# %%
words3 = list(chain.from_iterable([word for word in job] for job in tokenised))
vocab3 = set(words3)

# %% [markdown]
# ** This is an extra checkpoint to monitor the progress of purification

# %%
print(f"Length of words: {len(words)}")
print(f"Length of vocab: {len(vocab)}")
print(f"Length of words 2: {len(words2)}")
print(f"Length of vocab 2: {len(vocab2)}")
print(f"Length of words 3: {len(words3)}")
print(f"Length of vocab 3: {len(vocab3)}")
# Out:
# Length of words: 494596
# Length of vocab: 19932
# Length of words 2: 485423
# Length of vocab 2: 10759
# Length of words 3: 133724
# Length of vocab 3: 9776

# %% [markdown]
# ### vocab.txt

# %%
vocab3 = list(vocab3)

# %%
# list of final vocabs
vocab = {vocab3[i]:i for i in range(0,len(vocab3))}

# %%
# building a function to create th vocab.txt file meeting the task's requirements
def vaocab_output(file):
    with open (file, "a") as f:
        for key in sorted(vocab.keys()):
            f.write("%s:%s\n" % (key, vocab[key]))

# %%
# calling the function and build the file
vaocab_output("vocab.txt")

# %% [markdown]
# ### Parser.txt
#
# - Since I took on this task in the end, I realised all previous steps were included in this one as well.
# - As a result, I structured the whole code in a new format.
# - At this stage, I had a better understanding of the assessment requirement. So I structured the need more neetly.

# %%
data = {}
id = None
with open('data.txt', 'r') as f:
    for i, line in enumerate(f): # create the iteration in the range of imported file's length
        line = line.lower() 
        line = line.strip()
        if not line:
            continue
        section = line.split(':')[0] # define 'section' as a method to manupilate each line based on how the line begins
        content = ':'.join(line.split(':')[1:]).strip() # define 'content' a method to capture tokens
        if section == 'id': # id section:
            if id: # Error handle if theres some bad formatting: multiple ids
                raise ValueError('unable to parse file at line %d, multiple ids' % i)
            id = content[1:] # capture the job id
            if id in data.keys():# Error handle if theres some bad formatting: duplicates
                raise ValueError('unable to parse file at line %d, duplicate id' % i)
        elif section == 'description': #capture job description per each job ad
            if not id:# Error handle if theres some bad formatting: missing id
                raise ValueError('unable to parse file at line %d, missing id' % i)
            content = pattern.findall(line)
            content = [value for value in content if len(value) > 2] # remove short character token
            content = [value for value in content if value not in stopwordsset] # remove stopwords
            content = [value for value in content if value not in once_only] # remove lowFreq token
            content = [value for value in content if value not in highFreq] # remove highFreq tokens
            data[id] = content # creates data dictionary
            id = None
        elif section == 'title': # if the line start with 'title' do nothing
            continue
        else:
            raise ValueError('unable to parse file at line %d, unexpected section name' % i)

# %%
# Build output file:

with open('sparse.txt',"w") as f:
    for jobID,content in data.items(): # go through data dictionary created in the last block
        fd_parse = FreqDist(content) # count number of times each token occured in the same job ad
        tmp = "" # create a placeholder for word_index:word_freq
        for (x,y) in fd_parse.items(): # iterate through each frequencies
            tmp += f"{vocab[x]}:{y}," # build the dictionary of word_index:word_freq in the placeholder
        f.write(f"{jobID},{tmp[:-1]}\n") # write in the file line by line
